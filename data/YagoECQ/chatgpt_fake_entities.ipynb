# %%
import pandas as pd
import os

# %%
DATA_ROOT = "."
PRED_URI_TO_SO_PAIRS_PATH = os.path.join(DATA_ROOT, "yago_pred_uri_to_so_pairs_randomized_1k.json")
YAGO_QEC_PATH = os.path.join(DATA_ROOT, "yago_qec.json") 
YAGO_FAKE_ENTITIES_PATH = os.path.join(DATA_ROOT, "chatgpt_fake_entities.csv") 
# YAGO_FAKE_ENTITIES_PATH = os.path.join(DATA_ROOT, "chatgpt_fe2.csv")

# %%
fake_entities = pd.read_csv(YAGO_FAKE_ENTITIES_PATH)
fake_entities.value_counts(), fake_entities["FirstName"].value_counts(), fake_entities["LastName"].value_counts()
# Out:
# (FirstName  LastName
#  Aria       Andersson    4
#  Lucas      Patel        3
#  Arjun      Patel        3
#  Aisha      Al-Farsi     3
#  Mila       Moreno       3
#                         ..
#  Gabriela   Ferreira     1
#  Gabriel    Santos       1
#             Kim          1
#             Khatami      1
#  Layla      Rossi        1
#  Length: 386, dtype: int64,
#  Lucas        12
#  Eva          10
#  Aisha        10
#  Layla         8
#  Arjun         8
#               ..
#  Sebastian     2
#  Rajiv         1
#  Zain          1
#  Lucia         1
#  Javier        1
#  Name: FirstName, Length: 126, dtype: int64,
#  Andersson    54
#  Fuentes      53
#  Moreno       53
#  Patel        52
#  Al-Farsi     52
#               ..
#  Andreeva      1
#  Hassan        1
#  Delgado       1
#  Al-Abadi      1
#  Al-F          1
#  Name: LastName, Length: 144, dtype: int64)

# %%
set(fake_entities["FirstName"] + " " + fake_entities["LastName"])
# Out:
# {'Aaliyah Andersson',
#  'Aaliyah Johnson',
#  'Aaliyah Khan',
#  'Aaliyah Ricci',
#  'Aaradhya Al-Farsi',
#  'Aaradhya Mehta',
#  'Aaradhya Patel',
#  'Aarav Fuentes',
#  'Aarav Malhotra',
#  'Aarav Sharma',
#  'Aaron Patel',
#  'Aaron Ramirez',
#  'Adriana Al-Farsi',
#  'Adriana Santana',
#  'Ahmed Al-Abadi',
#  'Ahmed Andersson',
#  'Ahmed Khatami',
#  'Aidan Chen',
#  'Aidan Fuentes',
#  'Aidan Nguyen',
#  'Aiden Andersson',
#  'Aiden Chow',
#  'Aiden Fuentes',
#  'Aisha Al-Farsi',
#  'Aisha Andersson',
#  'Aisha El-Mahdi',
#  'Aisha Moreno',
#  "Aisha O'Connor",
#  'Aisha Saad',
#  'Aisha Suleiman',
#  'Akira Fuentes',
#  'Akira Khatami',
#  'Akira Takeuchi',
#  'Amara Andersson',
#  'Amara Chowdhury',
#  'Amara Moreno',
#  'Amina Ali',
#  'Amina Andersson',
#  'Anastasia Al-Farsi',
#  'Anastasia Fuentes',
#  'Anastasia Pavlov',
#  'Andrei Ivanov',
#  'Andrei Patel',
#  'Anika Al-Farsi',
#  'Anika Choudhury',
#  'Anika Moreno',
#  'Anton Al-Farsi',
#  'Anton Larsson',
# ...
