# %%
import json
import re
import os
import itertools
from transformers import ReformerModelWithLMHead

import torch
import random
import numpy as np

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
# Encoding
def encode(list_of_strings, pad_token_id=0, device="cpu"):
    max_length = max([len(string) for string in list_of_strings])

    # create emtpy tensors
    attention_masks = torch.zeros((len(list_of_strings), max_length), dtype=torch.long)
    input_ids = torch.full((len(list_of_strings), max_length), pad_token_id, dtype=torch.long)

    for idx, string in enumerate(list_of_strings):
        # make sure string is in byte format
        if not isinstance(string, bytes):
            string = str.encode(string)

        input_ids[idx, :len(string)] = torch.tensor([x + 2 for x in string])
        attention_masks[idx, :len(string)] = 1

    return input_ids.to(device), attention_masks.to(device)
    
# Decoding
def decode(outputs_ids):
    decoded_outputs = []
    for output_ids in outputs_ids.tolist():
        # transform id back to char IDs < 2 are simply transformed to ""
        decoded_outputs.append("".join([chr(x - 2) if x > 1 else "" for x in output_ids]))
    return decoded_outputs

model = ReformerModelWithLMHead.from_pretrained("google/reformer-enwik8").to(device)
prompt = "Something was created in the year [["
prompt = "The editor is named [["

encoded, attention_masks = encode([prompt], device=device)
decode(model.generate(encoded, do_sample=True, num_return_sequences=10, max_length=50))
# Out:
# ['The editor is named [[Samuel Howard Taylor]]. On S',
#  'The editor is named [[Herbert Brown (author)|Herbe',
#  'The editor is named [[Yongdan Chenguon]].\n\n== See ',
#  'The editor is named [[Merril Paul]] after him. A f',
#  'The editor is named [[Walter Walter]]. Prihe died ',
#  'The editor is named [[Alexandra Bulisc (composer)|',
#  'The editor is named [[Prince Charles Concord, Duke',
#  'The editor is named [[Richard RÃ©ditor (class war ',
#  'The editor is named [[Justine Debbie]] and 26 of t',
#  'The editor is named [[Robert Grouse]].\n\n* Several ']

# %%
def set_seed(seed=0):
    torch.manual_seed(seed)
    random.seed(seed)
    np.random.seed(seed)

# %%
def extract_entity(text):
    regex_pattern = r'\[\[([^\[|\]]+?)(?:\([^)]*\))?(?:\|[^|\]]+)*\]\]'
    # regex_pattern = r'\[\[([^\[|\]]+?)(?:\([^)]*\))?(?:\|([^|\]#]+))*\]\]'
    # regex_pattern = r'\[\[([^|\]#]+?)(?:\([^)]*\))?(?:\|([^|\]#]+))*\]\]'

    match = re.search(regex_pattern, text)

    if match:
        result = match.group(1).strip()
        return result
    
    return None

# %%
print(extract_entity("This event is known as [[Hansenschaft al Goten#sdf|Hansenschaft]].\n\n==History==\n''Main article: [[Histor"))
print(extract_entity("This event is known as [[Hansenschaft al Goten(disa)|Hansenschaft]].\n\n==History==\n''Main article: [[Histor"))
# Out:
# Hansenschaft al Goten#sdf
# Hansenschaft al Goten

# %%
entity_types_to_prompts = {
    "http://schema.org/CreativeWork": "The creative work called [[",
    "http://schema.org/Event": "The event called [[",
    "http://schema.org/Intangible": "The concept called [[",
    "http://schema.org/Organization": "The organization is called [[",
    "http://schema.org/Person": "The person named [[",
    "http://schema.org/Place": "The place is named [[",
    "http://schema.org/Product": "The product is called [[",
    "http://schema.org/Taxon": "The taxon named [[",
    "http://schema.org/FictionalEntity": "The fictional entity named [[",
}
entity_types_to_fake_entities = {}

# %%
for et, p in entity_types_to_prompts.items():
    set_seed(0)
    print(f"***{et}***")
    encoded, attention_masks = encode([p], device=device)
    res = decode(model.generate(encoded, do_sample=True, num_return_sequences=1100, max_length=100))
    # print(json.dumps(res, indent=4))
    extracted_res = [extract_entity(s) for s in res if extract_entity(s) is not None]
    extracted_res = random.sample(extracted_res, 1000)
    entity_types_to_fake_entities[et] = extracted_res
    # print(json.dumps(extracted_res, indent=4))
# Out:
# ***http://schema.org/CreativeWork***
# ***http://schema.org/Event***
# ***http://schema.org/Intangible***
# ***http://schema.org/Organization***
# ***http://schema.org/Person***
# ***http://schema.org/Place***
# ***http://schema.org/Product***
# ***http://schema.org/Taxon***
# ***http://schema.org/FictionalEntity***

# %%
DATA_ROOT = "."
PRED_URI_TO_SO_PAIRS_PATH = os.path.join(DATA_ROOT, "yago_pred_uri_to_so_pairs_randomized_1k.json")
YAGO_QEC_PATH = os.path.join(DATA_ROOT, "yago_qec.json") 
YAGO_FAKE_ENTITIES_PATH = os.path.join(DATA_ROOT, "fake_entities.json") 
with open(YAGO_QEC_PATH, "r") as fp:
    yago_qec = json.load(fp)

# %%
print(json.dumps({k: v["entity_types"] for k, v in yago_qec.items()}, indent=4))
# Out:
# {
#     "http://schema.org/about": [
#         "http://schema.org/Event",
#         "http://schema.org/CreativeWork",
#         "http://schema.org/Product"
#     ],
#     "http://schema.org/children": [
#         "http://schema.org/Person"
#     ],
#     "http://schema.org/director": [
#         "http://schema.org/CreativeWork",
#         "http://schema.org/Product"
#     ],
#     "reverse-http://schema.org/homeLocation": [
#         "http://schema.org/Organization",
#         "http://schema.org/Place"
#     ],
#     "reverse-http://schema.org/founder": [
#         "http://schema.org/Person"
#     ],
#     "http://schema.org/leader": [
#         "http://schema.org/Organization",
#         "http://schema.org/Place"
#     ],
#     "reverse-http://schema.org/lyricist": [
#         "http://schema.org/Person"
#     ],
#     "http://schema.org/manufacturer": [
#         "http://schema.org/CreativeWork",
#         "http://schema.org/Product"
#     ],
#     "http://schema.org/influencedBy": [
#         "http://schema.org/Person"
#     ],
#     "http://schema.org/iataCode": [
#         "http://schema.org/Organization"
#     ],
#     "reverse-http://schema.org/illustrator": [
#         "http://schema.org/Person"
#     ],
#     "http://schema.org/author": [
#         "http://schema.org/CreativeWork",
#         "http://schema.org/Product"
#     ],
#     "http://schema.org/dissolutionDate": [
#         "http://schema.org/Organization",
#         "http://schema.org/Place"
#     ],
#     "http://schema.org/elevation": [
#         "http://schema.org/Place"
#     ],
#     "reverse-http://schema.org/editor": [
#         "http://schema.org/Person"
#     ],
#     "http://schema.org/motto": [
#         "http://schema.org/Organization",
#         "http://schema.org/Place"
#     ],
#     "http://schema.org/lyricist": [
#         "http://schema.org/CreativeWork",
#         "http://schema.org/Product"
#     ],
#     "http://schema.org/founder": [
#         "http://schema.org/Organization",
#         "http://schema.org/Place"
#     ],
#     "reverse-http://schema.org/leader": [
#         "http://schema.org/Person"
#     ],
#     "http://schema.org/locationCreated": [
#         "http://schema.org/CreativeWork"
#     ],
#     "http://schema.org/lowestPoint": [
#         "http://schema.org/Organization",
#         "http://schema.org/Place"
#     ],
#     "http://schema.org/award": [
#         "http://schema.org/Person"
#     ],
#     "http://schema.org/address": [
#         "http://schema.org/Organization",
#         "http://schema.org/Place"
#     ],
#     "http://schema.org/highestPoint": [
#         "http://schema.org/Organization",
#         "http://schema.org/Place"
#     ],
#     "http://schema.org/isbn": [
#         "http://schema.org/CreativeWork",
#         "http://schema.org/Product"
#     ],
#     "http://schema.org/duration": [
#         "http://schema.org/CreativeWork",
#         "http://schema.org/Product"
#     ],
#     "http://schema.org/endDate": [
#         "http://schema.org/Event"
#     ],
#     "http://schema.org/demonym": [
#         "http://schema.org/Organization",
#         "http://schema.org/Place"
#     ],
#     "http://schema.org/administrates": [
#         "http://schema.org/Organization",
#         "http://schema.org/Place"
#     ],
#     "http://schema.org/illustrator": [
#         "http://schema.org/CreativeWork",
#         "http://schema.org/Product"
#     ],
#     "reverse-http://schema.org/author": [
#         "http://schema.org/Person"
#     ],
#     "http://schema.org/affiliation": [
#         "http://schema.org/Person"
#     ],
#     "http://schema.org/dateCreated": [
#         "http://schema.org/Organization",
#         "http://schema.org/Product",
#         "http://schema.org/CreativeWork",
#         "http://schema.org/Place"
#     ],
#     "reverse-http://schema.org/manufacturer": [
#         "http://schema.org/Organization",
#         "http://schema.org/Place"
#     ],
#     "http://schema.org/inLanguage": [
#         "http://schema.org/CreativeWork",
#         "http://schema.org/Product"
#     ],
#     "http://schema.org/contentLocation": [
#         "http://schema.org/CreativeWork",
#         "http://schema.org/Product"
#     ],
#     "http://schema.org/icaoCode": [
#         "http://schema.org/Place"
#     ],
#     "http://schema.org/gtin": [
#         "http://schema.org/CreativeWork",
#         "http://schema.org/Product"
#     ],
#     "http://schema.org/iswcCode": [
#         "http://schema.org/CreativeWork",
#         "http://schema.org/Product"
#     ],
#     "http://schema.org/leiCode": [
#         "http://schema.org/Organization",
#         "http://schema.org/Place"
#     ],
#     "http://schema.org/editor": [
#         "http://schema.org/CreativeWork",
#         "http://schema.org/Product"
#     ],
#     "http://schema.org/humanDevelopmentIndex": [
#         "http://schema.org/Organization",
#         "http://schema.org/Place"
#     ],
#     "http://schema.org/material": [
#         "http://schema.org/CreativeWork",
#         "http://schema.org/Product"
#     ],
#     "reverse-http://schema.org/director": [
#         "http://schema.org/Person"
#     ],
#     "http://schema.org/duns": [
#         "http://schema.org/Organization"
#     ],
#     "http://schema.org/homeLocation": [
#         "http://schema.org/Person"
#     ]
# }

# %%
entity_types_to_fake_entities
# Out:
# {'http://schema.org/CreativeWork': ['Devorage and Planning',
#   'Ptolemy',
#   'checkers',
#   'historical revisionism',
#   'Dialectic',
#   'Moon',
#   'funnies',
#   'meter work',
#   'Da Noroada',
#   'Gales Gales',
#   'The element of reality',
#   'time:service.',
#   'Autreas Smell',
#   'pregapassirin',
#   'Dr. Marginery',
#   'shaological creationism',
#   'Hilbert',
#   'odiana nature',
#   'Draging',
#   'Francis Grayson-Guler',
#   'Neu-O Day',
#   'Indonesia',
#   'dualism',
#   'Wiccan',
#   "Freeman's Globe",
#   'The Hubble White World',
#   'the Seven Awakes of the Discovery of Excellence',
#   'The Creative Works of Arube the Strauss',
#   'Dr. Martin Boom',
#   'Jerem Lowe',
#   'creative complex',
#   'denset metalogy',
#   'Vertebra',
#   'Blue the Apple',
#   'Creative Communication',
#   'Mineralism',
#   'Mithah',
#   'Robert G. Gordon',
#   'Process',
#   'Darwin Forkes',
#   'Valkyrie',
#   'The Market Whise Fire',
#   'blending',
#   "Devil's Feathers",
#   'Libsations',
#   'Creative Heavenly Forces',
#   'Huffman zovigina tovigina',
#   'logs',
#   'Adely Goldberg',
#   'Kajbasisine',
#   'interpolation',
#   'Hercules',
#   'Chun, the Smart Works of T. S. Ford',
#   'Cain Jam',
#   'Rene De Jour',
#   'God will be the Mask of Mission',
#   'Contemporary Flait',
#   "Worksus' Creative Works",
#   'dualism',
#   'Hersopolis',
#   'Epistemology',
#   'Boods &amp; Geographies',
#   'creativistus',
#   "Fullmember's Creative Works",
#   'Works of Anthropology',
#   'Philip Pearce',
#   'nightmarish',
#   'Vita Crevi',
#   'Gandhi Buddhism',
#   'Vengens',
#   'The Beasts.',
#   'Wide Brack Cassette',
#   'Whitefridge company',
#   'biogeochemistry',
#   'Gaothi Mankaka',
#   'William Browning',
#   'profraction',
#   'physiologia',
#   'Dementis Demetrio',
#   'Ludwig von Mises',
#   'creativity',
#   'magical personality',
#   'William Williams',
#   'Denoramism',
#   'futuro',
#   'astronomy',
#   'Chattahooches',
#   'Liberal American Football',
#   'Virginia',
#   'Andrew Salviut',
#   'Thematico',
#   'Scottish Devotional Visual Initiative',
#   'Protestantism',
#   'Creativism',
#   'Ludwig van Beethoven',
#   'nynonon',
#   'Handel',
#   'niche movement',
#   'Versig Leves',
#   'aphodic diagnosis',
#   'Plot brother',
#   'Machina Scisso',
#   'Progressive Anecdote',
#   'idealism',
#   'Evolution of the Order',
#   'Vom Mandelboro',
#   'Auner D. fAttis melody',
#   'Marvel Universe Marker',
#   'Dardanelles',
#   'Duluth',
#   'Lady Danner',
#   'Sensationalism work called Manifesto',
#   'pelvis',
#   'Dione',
#   'Godlik',
#   'Wikipedia',
#   'Tranformation',
#   'properties',
#   'successor creativity',
#   'Dione',
#   'Kurthusianism',
#   'captivismi',
#   'Dulus the Alexandrian',
#   'Old English language',
#   'Derivative work',
#   'hegemony',
#   'Worksins',
#   'Blue Works',
#   'The Mysinion Directions',
#   'Piedmont',
#   'Brown',
#   'Senesos',
#   'Primulus',
#   'Gonswana',
#   'sarcophagus',
#   'cinema of the United States',
#   'Dyars',
#   'Josaph Louis Lagrange',
#   'Creative Beat',
#   'Radical Change',
#   'Buck Morris',
#   'Die Histoirelle',
#   'mixsickers',
#   'auteus',
#   'Archibald Socon Problem',
#   'circumflexion',
#   'nide variable',
#   'Neine Bannoon',
#   'Demolishing the Demolishes',
#   'realism',
#   'figure of freedom',
#   'Venka Parta',
#   'Kikkunil',
#   'Rubenson',
#   'syntnesis',
#   'death due to great appearance',
#   'Fellnickie',
#   'Heror of Humanity',
#   'Ascension',
#   'twistic point',
#   'Hodges Texas',
#   "Goin's Rough Angel",
#   'sexual entity',
#   'creationism',
#   'Creative Contract Storage',
#   'Jungiella',
#   'creative expression theory',
#   'analogue testing',
#   'Hermitius',
#   'The Devil',
#   'hermit',
#   "Devil's Devil",
#   'Second World War',
#   'intertextualism',
#   'Modernism',
#   'Doing',
#   'hanry faith',
#   'The Triumph of the World',
#   'MÃ©tis',
#   'Yes Series',
#   'Abrahamic religion',
#   'Calculations',
#   'antiquity',
#   'morality',
#   'Jeremy Baptist',
#   'George Jacob Schiffer',
#   'The Wild Mun',
#   'Quinines',
#   'Creative Theism',
#   'Leopard Vendewick',
#   'Fine Sweet Dark Meat',
#   'Fism (fism)',
#   'Cseative',
#   'Apple Computer',
#   'virilogic',
#   'Harry Cooper',
#   'Lenny Tzomer',
#   'Little Works Original Source Berger',
#   'Dr. Ward',
#   'tin',
#   'Preslan',
#   'productive work',
#   'The Doors',
#   'Athena',
#   'Markaldine',
#   'Autocroft',
#   'member states',
#   'Howthorne',
#   'The Sprint',
#   'Trimer',
#   'Merlin',
#   'The Two Once Testaments',
#   'Huntington creative work',
#   'The Answers',
#   'List_of_poets_by_Berlin_poets',
#   'invertebral pressure',
#   'Absentia',
#   'Trantata',
#   'The Byron',
#   'propoetics',
#   'creativism',
#   'Silver:Animation',
#   'Creation Overton',
#   'Xenadia',
#   'demigram',
#   'thought experience',
#   'project X',
#   'the Bamboot',
#   'Lex soccer',
#   'statutory liberalism',
#   'Orcheson',
#   'mosasai',
#   'Noble Works',
#   'Herstories',
#   'Ursula Reborn',
#   'billion',
#   'William Wilkinsot Mikhailov',
#   'Didi',
#   'Divine providence',
#   'repucive repucive attack',
#   'Elliot',
#   'Snorkell',
#   'Aft-Pop. The Third Reich',
#   'John Longden',
#   'Godarioda',
#   'Don an Award',
#   'From Beauty',
#   'Hersigo',
#   'Didache of Temela',
#   'habeas creative',
#   'ZenÄ\x9bn',
#   'Gerald Barbarosse',
#   'pseudoscope',
#   'internet policy',
#   'MediaWiki',
#   'Devil the Creative Work of Devil the Manchester',
#   'Flase of the Legend of Zegend',
#   'New South Wales',
#   'Enlightenment',
#   'neolithic',
#   'Work',
#   'reed',
#   'Trotskyia',
#   'Creature',
#   'Call of Cohonna',
#   'Print the Press',
#   'Work of the Dead',
#   'funeral',
#   'The Foreseen Blood',
#   'Kirsai Emerial Grbaciz',
#   'Pratigue of return',
#   'Commanding extranets',
#   'World Wide Web',
#   'Goidiosis',
#   'Fogens',
#   'to solve the theory of law',
#   'Kaisos, Jewish dramatist',
#   'Scunagura',
#   'Enoch (creative work)',
#   'Manila Work',
#   'Alfison Ford',
#   'leaf-soaped ash',
#   'porn works',
#   'Sergis Salegdi',
#   'Mysiodorus',
#   'Leo Tolstoy',
#   'Origin of Ancient Greece',
#   'Nilly Creative',
#   'creationism',
#   'Bessian creativism',
#   'theodosis',
#   'Creative Comotive Packing',
#   'sinena',
#   'reeligk',
#   'Delander &amp; Solomon',
#   'philosophical dream',
#   'The Books of Mankind',
#   'The Cynic Model',
#   'Critique of Media',
#   "The Adam's Full Work",
#   'Origin of Religion',
#   'Conspiracy theory',
#   'Death Row Row',
#   'catapult',
#   'Dope',
#   'WobFour',
#   'sinfuncing',
#   "Peter O'Neill",
#   'Preachers',
#   'grams',
#   'creativism',
#   'Lecies',
#   'Anthony the Great',
#   'The Divided Blue Slue',
#   'Introduction',
#   'product',
#   'Gratiful Depression',
#   'Dianica',
#   'archeology',
#   "Epstonia's Trilogy",
#   'Workstations',
#   'The Creative Work',
#   'Creativistism',
#   'Authorship of Conflict',
#   'Derivatives',
#   'Motivations (fiction)',
#   'Primitive work',
#   'Dute',
#   'theology',
#   'Defiant Dragon',
#   'Creative Composition',
#   "Slave 'sugar",
#   'George Mason',
#   'M. S. &quot;Middle&quot;',
#   'Reslogion',
#   'Subject Verse',
#   'sin working',
#   'Berlin',
#   'Autobons',
#   'John Tudor',
#   'The Protector',
#   'Charles B. Douglas',
#   'Integamator',
#   'The Official Movies',
#   'Agrippina the Byzantine',
#   'Flasderster',
#   'negative and non-negative personality',
#   'Lord Maulik',
#   'chapmania',
#   'Tralih of Love',
#   'creature culture',
#   'Creative Consciousness',
#   'directive work',
#   'resonance flow',
#   'American American meridian',
#   'Reproductive Constantine Series',
#   'possum',
#   'Deus Ex',
#   'Vestibuli Oplenitus',
#   'Guest Force',
#   'Lyman Word',
#   'Real Turk',
#   'invocation',
#   'The Pratchett',
#   'non-platanus',
#   'The Last Music',
#   'Semi-Out Oft',
#   'The creative works of Frederic Derbys',
#   'Intolerant Explosion',
#   'Amnesh Bowd',
#   'homosomy',
#   'Black',
#   'Creative Transformation Language International Programming',
#   'Alexander Hackett',
#   'Harry Nelson',
#   'naturalism',
#   'Plan de la reine',
#   'Mercury',
#   'recitative',
#   'Energetics',
#   'the Lookout Trilogy',
#   'Orthodox Theologianism',
#   'Analytica',
#   'Popular Surgery',
#   'creature eggs',
#   'Lebanon',
#   "Dr. Riba d'Arra",
#   'creative control',
#   'Chainmail',
#   'Ontonio FÃ¼hrer',
#   'the Creative Act of 1988',
#   'the Teenage Creative Classification',
#   'Death of Ross Island',
#   'divergentism',
#   'inconcept',
#   'annaxes',
#   'radio data transmission',
#   'crest of previous events',
#   'physecological composition',
#   'The True Bemony',
#   'Ethics',
#   'Christianity',
#   'Flitts',
#   'Selfisal Spaces',
#   'Dr. Gladin',
#   'Horror factor',
#   'mutation',
#   'Wire',
#   'allallal',
#   'Cell o the Beorus create the contents of ancient Egypt',
#   'Braille and Mold',
#   'Yes Creative Work',
#   'Sri Lanka',
#   'genetics',
#   'Doris Duris',
#   'The Municipality',
#   'Americans',
#   'Bertrand Russell',
#   'dialectal defense',
#   'Hermando Fossetti',
#   'Joseph Haydn',
#   'Denmark',
#   'The Herninger',
#   'morphogia',
#   'creative contract',
#   'delucritus',
#   'Malta',
#   'Doris Diampora',
#   'De la Rue Ã\x89bou-Sur',
#   'The Blue Law',
#   'Ag and Allways',
#   'Ludwig von Messerprand',
#   'Creation Science',
#   'mrawl',
#   'God',
#   'Adam and Eve',
#   'Dyson scrolls',
#   'Skyscrapers',
#   'diabetes',
#   'Illumisis',
#   'Remiracking Marriage',
#   "Motor's Work",
#   'habbit',
#   'Creative closing',
#   'Robert Fussel',
#   'historical evolution',
#   'onionism',
#   'intelligent design',
#   'Creation color',
#   'Abel Sedgwick',
#   'Hylstock Marathon',
#   'Poaceae',
#   'Grant Welch',
#   'Anares Madrid',
#   'Howard Sibtler',
#   'A Hanging',
#   'prapo',
#   'superstarus',
#   'Pelry and the Travelsable Works',
#   'allegory',
#   'Modern History Modern History',
#   "Darwin's Gate of the Rifle Bridge",
#   'Arthums creative work',
#   'Aide-Tide',
#   'the Herlington Fair',
#   'nymph intervention',
#   'cuesava',
#   'Zonand',
#   'politics',
#   'Assak and Dante',
#   'Dark Energy',
#   'nodemic',
#   'tensor creative',
#   'theme',
#   "Learner's Lab",
#   'Kingping',
#   'cyninder',
#   'evolution',
#   'Nasi reeds',
#   "Platt's Creative Work",
#   'Sedative work',
#   'Dwight D. Eisenhower',
#   'The Tomlins',
#   'buttercup',
#   'saturation',
#   'Rene Anne Arne',
#   'Lord Mayo',
#   'creationism',
#   'Gracinus',
#   'Old Alexander Thomas',
#   'Slasher',
#   'intelligent design',
#   'Pratt &amp; Whitneys',
#   'Subtimes Random House',
#   'Exsenses',
#   "Dr. Wil' Mountain",
#   'Dylan of Paradise',
#   'Omnimomisus',
#   'creative copy',
#   'Franz Kafka',
#   'Grace',
#   'Draggins',
#   'nyponym',
#   'number theory',
#   'licensure',
#   'Dishquishingseek',
#   'hypothesis',
#   'prototype-work analysis',
#   'alter-ego',
#   'Scifsordeninger Scifsordininger',
#   'Creative Action',
#   'beauty',
#   'The Plan to Number The Creative',
#   'Portable Field Organization',
#   'Logistics',
#   'himming',
#   'We',
#   'The Beat the Rafter',
#   'mystics',
#   'Death Which 24',
#   'science fiction',
#   'Loss School',
#   'preprinter',
#   'mizler work',
#   'karamazom',
#   'Desmartosmos',
#   'realism',
#   'Elfqnort',
#   'Alfin Moscow Tilbury',
#   'Hubbard university',
#   'World Grand Prix',
#   'Danny Wilson',
#   'Funrahman Ahmad',
#   'niche the mind',
#   'The Oufhof Prange',
#   'Trapeze',
#   'via regenerative crisis',
#   'Homer lover',
#   'The Nature of attraction between earthquakes and plants',
#   'Neoread',
#   'cosmological',
#   'The Creative Productive Universe',
#   'eroticism',
#   'Doctrine of the Creative Presence of the Biblical Presence',
#   'Amorgos',
#   'casonine',
#   'Steel structures',
#   'novel',
#   'Led Zeppelin',
#   'The Cascade',
#   "Fulhard's Saturn",
#   'Great Legion',
#   'Darx, Alaska',
#   'Duodenius Duodenus',
#   'Creative Case',
#   'sabinet',
#   'Osfahi Osfahila',
#   'electricity',
#   'Dutch Mare',
#   'To do so',
#   'Autocrat',
#   'Thebatorial',
#   'Exclave',
#   'Michael Say',
#   'Hercule Plan',
#   'old contrast',
#   'Indian Jungle Mercury',
#   'Dr. William Howe',
#   'the Queen',
#   'subincisio',
#   'work',
#   'the Outline of Information Technologies',
#   'Smirton model',
#   'Self-Gomination',
#   'Dante David Martin',
#   "Creation of A'Three",
#   'Iphynocrystes',
#   'Calvary Bayshot',
#   'Dyson Theory',
#   'metamorphoses',
#   'Titano',
#   'Dada',
#   'Work-wire',
#   'Drave The Third',
#   'da capita',
#   'prose',
#   'creationism',
#   'The Plutocreachers',
#   'Durrence',
#   'Infonmesia',
#   'virus',
#   'Slave the Red',
#   'theimmimtim',
#   'The Dark Shadow',
#   'Modern Modern Modern',
#   'Nature',
#   'atomic weight',
#   'single origin',
#   'Michael Moorcock',
#   'creative Commodity',
#   'Joseph Sleden',
#   'Culp',
#   'Origin of Spoken Words',
#   'Hilderjee',
#   'William Blake',
#   'Clouds',
#   'Treadulus',
#   'Works Transfer Dossier',
#   'divinity art',
#   'Persevolonia massacre',
#   'nuclear weapon',
#   'Flessen effemds',
#   'Autobiography',
#   'Reme',
#   'greenpeace',
#   'creator',
#   'Pes Lehiqse',
#   'Atob Flake',
#   'Determinismism',
#   'Labour Day',
#   'French Appilistic Missile Around French Resistance',
#   'universalism',
#   'H.G. Wells',
#   'fiction',
#   'gospel of the Christ',
#   'Gothic',
#   'promoting materials',
#   'Quotation',
#   'The True Golden Ages',
#   'Ring',
#   'time',
#   'Wiktionary:Wiktionary interpretation',
#   'Karlsruhe',
#   'Duck',
#   'The President',
#   'Intelligent Developments Intelligent Development Systems',
#   'Fridolin Hercules',
#   "Themas's Work",
#   'creative development',
#   'Libot',
#   'ne-thinking',
#   'shilling',
#   'Viciouson Hereditary Viciouson',
#   'claising the field theory',
#   'Octavius',
#   'Patthazor',
#   'Dione',
#   'Madesville',
#   'Libertatiss',
#   'town chistitis',
#   'urban legend',
#   'Don R. Lay',
#   'Karma Works',
#   'H-H-B/S',
#   'prise',
#   "Graham's Lost Secret",
#   'Ed Brady',
#   'Homer',
#   'MÃ©rÃ©dÃ©es Ã©latin',
#   'Danly Wallace',
#   'dark creative work',
#   'Prometheus for the Moon',
#   'Wird wire',
#   'Telitus',
#   "Moore's Law",
#   'neologism',
#   'The Age of Brunned Beard',
#   'double ennethe',
#   'evil creative work',
#   'Creatiability',
#   'axiality',
#   'problem of chance',
#   'Death Warrior',
#   'Deros',
#   "Devil's End",
#   'Herodotus',
#   'wiktionary:wiktionary',
#   'George Gordon Byron, 6th Baron Byron',
#   'BÃ©rald Kelly',
#   'the Red Scare',
#   'Yoga',
#   'Wilbur',
#   'piano',
#   'nursery',
#   'Afinaby',
#   'fist fist',
#   'the Origin of Species',
#   'The Domain of the Power',
#   'prose',
#   'piercing',
#   'Be Shabi',
#   'the Yellow Father',
#   'transformation',
#   'Apennine Work',
#   'goddess invention',
#   'Lois of Simon',
#   'abababa',
#   'Felice Felice',
#   'Tsarevichy',
#   'human race',
#   'Blackheath',
#   'Xanthez melanoleucoque',
#   'Death (Death Theology)',
#   'peer-review',
#   'renardo',
#   'Time',
#   'Ã©cole consensus',
#   'planarkia',
#   'wedge effect',
#   'Kobayan',
#   'Ding Laden Amendment',
#   'Enigma',
#   'interphetical feature',
#   'Religionism',
#   'Gypsus',
#   'Harlan Ellison',
#   'Rayber Rayber Rayber Rayber',
#   "Elcher's Magillan",
#   'Flashback',
#   'Deseret Freedom',
#   'progrimming language',
#   'Hitchcock',
#   'Drund',
#   'Jewish Tewriter One',
#   'Cartography',
#   'Instrumental storm-setting',
#   'Antoine Camp',
#   'Capel',
#   'The Warm-Skinner',
#   'Formalism',
#   'Henry Goat Tour',
#   'song of a song',
#   'Franland Dennona',
#   'Sheol',
#   'Diablo the Magician',
#   'GenÃ¨ve',
#   'Creation Work',
#   'Net Cartron',
#   'Such Works',
#   'Original Skeleton',
#   'Reymond in the Third World',
#   'Works Almanac',
#   'Phrenology of Attributions',
#   'The Principles of Conclusion',
#   'Hermitima',
#   'The Agrippanilla',
#   'Ketouth',
#   'retrobrint',
#   'architecture',
#   'Skeldolatresus',
#   'The Fall of Soul',
#   'preprepige titching',
#   'error reflection hypothesis',
#   'Confidence and Professional Love',
#   'The Anrick Seagal Administration',
#   'predestinative work',
#   'work dance',
#   'Mail',
#   'Works of Skeleton',
#   'peasine',
#   'The Velusin and the Orange of Valisin',
#   'world war peace',
#   'Ineralary Development',
#   'Descache',
#   'The Bull',
#   'morality',
#   'Librevians',
#   'Christopher Albert Mead',
#   'Jivez encounter theory',
#   'Merred Brief',
#   'Graewald',
#   'fiat polemic',
#   'Michael Morrism',
#   'Ket the Blues',
#   'Bronze Age',
#   'Works in Addition to Abstraction',
#   'virtue equivalent equivalent',
#   'Dehumanization',
#   'Masonic',
#   'Fuduhara',
#   'Voyage of the Dominion',
#   'Nonhuhanna',
#   'God Exists',
#   'the Tragic Attack of the Comedy Centre',
#   'Ruth Keene',
#   'Doom',
#   'Gripmon',
#   'Brian Boney',
#   'Arab Death',
#   'well-vowel',
#   'Vertor Detective',
#   'Creativity',
#   'Otranto',
#   'Nanne Sotene',
#   'Deavor and Rights',
#   'archaeoarchaeoarchaeoarchyaeoid',
#   'Mazan Garo Garo',
#   'Dory Dory Dory',
#   'piercing',
#   'Aptitums',
#   'Asio Santo',
#   'preams',
#   'freedom of religion',
#   'Futurama',
#   'anachronous',
#   'phenomenology',
#   'Defense',
#   'Pritching the Telephone',
#   'Lottery mits',
#   'myths',
#   'Symphony No. 4',
#   'Thomas Hugo Clausewitzs',
#   'CIVOLD',
#   'Sanita Works',
#   'asteroid',
#   'genealogy',
#   'Conversion of fiction',
#   'Dewiyoto Okatomi',
#   'natural law',
#   'creative',
#   'Mesisen',
#   'Morph Morph',
#   'The Triumph of the Republic',
#   'Creative Cobalt',
#   'equation',
#   'hard writing',
#   'Direction',
#   'The Atheism',
#   'Junkoche',
#   'fatty',
#   'Karl Karl',
#   'D.P. Down',
#   'Derby Creative',
#   'altrubism',
#   'Napana',
#   'The War of the Worlds',
#   'creative control',
#   "Halley's Market",
#   'Le Gerinne',
#   'The Gung',
#   'Exhaustive American Volunteers',
#   'creative horror',
#   'Crucifixion',
#   'The_Slow_Science',
#   'folklore',
#   'mythology',
#   'Dr. Gideonsky',
#   'Giovanni Giovanni Sinores',
#   'World War I',
#   'Jurassic rabbit',
#   'Thing on the Good Shepherd',
#   'middle class',
#   'de:Deutsen Bede',
#   'Andromon',
#   'Worcestershire Anthology',
#   'racism',
#   "Gonlus' Faber",
#   'Tjadarsi',
#   'beauty',
#   'Mechanism',
#   'Machiavelli',
#   'Ontology',
#   'parrasro',
#   'Adolf Hitler',
#   'nonsense work',
#   'the demigning fitting',
#   'Creative Culture',
#   'Quaeser',
#   'Plato',
#   'frame back',
#   'historicism',
#   'Chordate',
#   'Jespian Creative Work',
#   'by J. Kamer Siddleton',
#   'exeter',
#   'The_Asterix_an_Asterix',
#   'Blizzard',
#   'piece trigger',
#   'Edward Kaunwick',
#   'Plutarch',
#   'Dr. Martin Wood',
#   'Case and Violence',
#   'naimsmen',
#   'mesitation of mesitation',
#   'Creatis work',
#   'Doctor Letters',
#   'Audiborio',
#   'The Threepsines',
#   'Spike',
#   "Charles's Darwin the Dude",
#   'Vincent Vaul',
#   'prose',
#   'Music',
#   'gound work',
#   'creativism',
#   'delimitation',
#   'Diogenes',
#   'passage',
#   'Brian Green',
#   'El Breto, the Horse and his Smokes',
#   'Kanasowit',
#   'The Southern Participation of the Barbarian',
#   'Hegel',
#   'papyrotype',
#   'The Dark Ages',
#   'Paul John',
#   'David Bushnell',
#   'Guillaume Guillaume',
#   'astronomy',
#   'Basqua Works',
#   'Work',
#   'photo-Optuki',
#   'The Cyril of Chesnur',
#   'Joseph Haydn',
#   'Aramnatiana',
#   'Placidy (magic)',
#   'Genesis',
#   'The Creative Principle',
#   'sutela',
#   'JÃ¡n del BornerÃ¡ndez',
#   'Hall of Darkness',
#   'Enrico Dalmorposa',
#   'Stormsryke',
#   'Kreek',
#   'David Borgh',
#   'creative work',
#   'The Creative Scorn',
#   'creative control',
#   'Deathbird',
#   "Gung's Gung",
#   "Lenford's Creative Bauhausen",
#   'Wors (Wors',
#   'Arthun',
#   'The Type of Creative Work',
#   'conversation}',
#   'The Anthology of Man',
#   'Menbish',
#   'Caul the Creative',
#   'Ferratif',
#   'Novara',
#   'creative backbone',
#   'cross-of-world',
#   'Hortetulusdins',
#   'Caeneid',
#   'Thennon',
#   'Gothic society',
#   'pierre',
#   'neurobiology',
#   'Sloop',
#   'Goshili Bhagavata',
#   'Workingmingmangang',
#   'Pre-Polity',
#   'Meta-encoheremistry',
#   'Creative Creative Creative Work',
#   'Death of the Murder',
#   'In vivis',
#   'beliuf',
#   'Liberted TheFathers',
#   'The Arts',
#   'Richard Taylor',
#   'Aresilionisms',
#   "Prisrie's Prisoner",
#   'Bletchley',
#   'Mentality',
#   'Kolog',
#   'Grasskow Amblyroth',
#   'Attractive Interior Work',
#   'Strategoid',
#   'de-Afim the accepted master',
#   'Definition#Creative_creative_creative_movement',
#   'Independence Day',
#   'Incremita e creativa',
#   'Doctor of Philosophy',
#   'self-similarities',
#   'Drummon',
#   'Creative Action',
#   'Ludwig Mortelsborough',
#   'Paul Calling',
#   'Workskills',
#   'Hyatt',
#   'Snorri Sturluson',
#   'Divinity Divinity',
#   'Principia Malibon',
#   'Theopopoenia',
#   'Helennor',
#   'TÃ«tÃ«s peoples and TÃ¡tÃ«s',
#   'mythology',
#   'realism',
#   'Sloka',
#   'retrofeter',
#   'worklibghing',
#   'The Untold Brain',
#   'Hilto Memorial Hilto',
#   'double-plating',
#   'telescopic setting',
#   'Binding',
#   'John Foster',
#   'FireWire',
#   "GÃ¶del's postulates",
#   'Pnisteriom'],
#  'http://schema.org/Event': ['allal survivor',
#   'Cruta Goneus',
#   'Welso',
#   'previous event',
#   'to shock',
#   'the Treaty of Utrecht',
#   'MediaWiki',
#   'Tamitza',
#   'Gematitis',
#   'Tatter of Foretand',
#   'piekette',
#   'turnoa',
#   'Herwegian: the Wind from Richard',
#   'CIA comparison',
#   'The Roots',
#   'Belaide University',
#   'death metal',
#   'TV Griffin hip hop music',
#   'Tikatoo nam Towatoo',
#   'T. Guerrald',
#   'historic historiography',
#   "Devil's Theory",
#   'Event Alonto Down',
#   'One Till Death',
#   'Callier',
#   'problem of chance',
#   'Judaism',
#   'Helloworth is the second time',
#   'Drone',
#   'The Smells',
#   "Event Called Utar'",
#   'Time Machine',
#   'historic present',
#   'When Lord the Force',
#   'historical context',
#   'Miles Thomson',
#   'race crisis',
#   'shock therapy',
#   'World War II',
#   'Tully-air',
#   'hypoxiability',
#   'praying',
#   'the Dark Knight',
#   'Should Is Done To See',
#   'Time of Happiness',
#   'Rabeesian movement',
#   'mirfield',
#   "The Hero's Hidden Hidden Character",
#   'Dido',
#   'Goar War',
#   'fitness times',
#   'Moon god',
#   "exeter's slash",
#   'Time Wind',
#   'Teleglography',
#   'Takkett',
#   'Fire Fuel',
#   'error reflection hypatation retention',
#   'Preaching',
#   'Halloween',
#   'set theory',
#   'Darkness',
#   'Tallade',
#   'Continuing Wiresatellite',
#   'List of meetings of sail',
#   'The Event Committee',
#   "America's Cup",
#   'temporary heating',
#   'horse',
#   'Mithah',
#   'machiabocar',
#   'Judaism',
#   'The Darkness',
#   'cauld',
#   'reptactive deception',
#   'no-thing',
#   'Kalled George Hornmoore',
#   'Terton Scholering',
#   'Ipuh oc side',
#   'Tate states and soldiers',
#   'Demeter',
#   'jaggie',
#   'Sormilaular Prime',
#   'suthea',
#   'full force',
#   'the Slave Happy and Other Stories',
#   'Forana',
#   'Old English Scottish Scotland Scotland',
#   'So A Mummy Week',
#   'Happiness',
#   'One Pistol',
#   'Meorah',
#   'slim-fighting',
#   'morris',
#   'Masterboy masterboy',
#   'Who are The Truth',
#   'Ofinian Gang',
#   'succession',
#   'on memory',
#   'Buckminster Fuller',
#   'Raphael',
#   'Fligtstones',
#   'Incubriative Development',
#   'Sdystzik',
#   'Traumatvi bha Shashi',
#   'Tommy Duck',
#   '1981',
#   'Before Chance',
#   'Hercules om Sport',
#   'Throw',
#   'Agripoli',
#   'War on Temporal Terror',
#   'Trifionomachthondontinate event',
#   'spytning',
#   'SLQ',
#   'Edward Kaunwick',
#   'One Turn To B.',
#   'the event',
#   'summation',
#   'Takeo the torsidoa',
#   'sabbati',
#   'Boot Law',
#   'Mac rove',
#   'Haphael',
#   'Telefontine',
#   'halo event',
#   'World Events',
#   'Taka Akirasa',
#   'mastirat',
#   'Statistics',
#   'Character clause',
#   'Overmorters',
#   'Comrade',
#   'Instrumental spots of six pieces',
#   'sarcophagus',
#   'nideria',
#   'Herwolf',
#   'Judaism',
#   'the Seven Awerents',
#   'The Descent of Distress',
#   'collective sale',
#   'The Huskell',
#   'Unruly Ruly',
#   'Event Act}',
#   'Suflag',
#   'Slow Force',
#   'chapleshop',
#   'Martyr',
#   'The Firm,',
#   'return',
#   'William Brown Rice',
#   'Event Clabs',
#   "Blake's Song",
#   'Caul collin',
#   'Event Change',
#   'The Most Doctors',
#   'torsus',
#   'Switzerland',
#   'The Event: Called War#Jimbo on the Called War',
#   'habykuska',
#   'Taliban',
#   'Delandante',
#   'Habbalah',
#   'Tortun-Level comparative theory',
#   'Ultraviolet None',
#   'Reymond, paradox of streams',
#   'Timeline of Understanding The Birth of Christ',
#   'the Age of Events',
#   'Aunerstanding',
#   'the Keyre accident',
#   'Jesus',
#   'Wikinews',
#   'The Event Called Galactical Highway',
#   'Traveling Town',
#   'Heron of Heron of Heron of Heron',
#   'Calculations',
#   'hands factor',
#   'mortality',
#   'wedding',
#   'Saint Boniface',
#   'Corrosa',
#   'Allie MeÃ¤reh',
#   'French theather',
#   'Call of The Complex Numbers',
#   'The Venus',
#   'Genova Jubilee',
#   'Bronze Age',
#   'Blizzard of no Court',
#   'Danny Weatherbies',
#   'Valium',
#   'claising the field',
#   'Time Savernor',
#   'spider doll',
#   'Wright-Rash',
#   'Ireland',
#   'high crisis of 24th Century Intercourse',
#   'Carnival history',
#   'Epentille of Fuan',
#   'Adult Child',
#   'time travel',
#   'MaBD',
#   'Omthodox_priests',
#   'The event',
#   'Thematorogautica',
#   'Cher id Incher',
#   'Darleep Darleep',
#   'Plutarch',
#   'Game of Onlyre',
#   'Hamm Fur',
#   'The Cunctation',
#   'The Alamedis War',
#   '20,40 Doors',
#   'The Capcas',
#   'Contino, novelist and playwright',
#   'Valle master',
#   'Horizontally',
#   'Tertatite',
#   'disabled',
#   'Flow on Money',
#   'Wiccadii',
#   'Termynade',
#   'Rotten event',
#   'The Temptation',
#   'diabolic in nature',
#   'Strategoid',
#   'Tell Transformation',
#   'The Event',
#   'The Official Movie',
#   'Lex scale',
#   'telford',
#   'fishing',
#   'Crusader Strategometer',
#   'event minimalism',
#   'David Hemlin',
#   'Sri Lei Perpeneous',
#   'Blasphemy',
#   'Huarta',
#   'hurk',
#   'The Triumph of the Events',
#   'urban heart rate',
#   'Whitefree of Whitefree, Dessert',
#   'Harmony',
#   'Tooth Of The Outside Calculation',
#   'Judaism',
#   'The Phantom Show',
#   'Sauders of Delta',
#   'Old Town, British Columbia',
#   'United States Book Awards',
#   'The Britannica',
#   '#The Full bank',
#   'Heavens Holy',
#   'Dory Dory Dory',
#   'good futures',
#   'Hellbark Hellbark',
#   'nine-hole event',
#   'Kings Shea',
#   'Nova Mesoda',
#   'The Regrets',
#   'Event Cauch Allanta',
#   'self-themenation',
#   'terrine sailing sailing',
#   'Reconfiction',
#   'afterlife',
#   'Sedata Therapyus',
#   'Out of the Edge of Fitna',
#   'The Two Ones',
#   'Teresius collabelli',
#   'Trichuille',
#   'mixsick',
#   'Time-Limax',
#   'Caihf and John of Ried',
#   'Stormon',
#   'novel',
#   'Golden Globe',
#   'Novation_',
#   'Tamifs',
#   'Terry Pratchett',
#   'high volume rate',
#   'Talking Ardents',
#   'Orbital_events',
#   'Condurrence Danger',
#   'Olt Ivan',
#   'Moon theory',
#   'The Untold to the Detroit Tide',
#   'pathological',
#   'The Man in the Mitchell',
#   'Determinism',
#   'Tillywoll',
#   'Calvidism',
#   'Ocean Epline',
#   'Dodge',
#   'Turn',
#   'Ursula Reborn',
#   'To stor the region',
#   'Combat master',
#   'Nonhuhamih',
#   'motto',
#   'Raelian',
#   'The Darkness Falls',
#   'Great Short Rule',
#   'hitherto regent',
#   'event of the event',
#   'Shirton Iron Front',
#   'wikt:keep',
#   'Labatutus',
#   'croclade',
#   'Europa Europa',
#   'Snorkell',
#   'horrent event',
#   'sexual relationship',
#   'Dada',
#   'Tertur Sumnolu',
#   'October 14',
#   'Wave twinsies',
#   'Subkty Assistant',
#   'libertine technology',
#   'Guinness Brothers',
#   'The Event Criterion',
#   'Tube Ti Arabic',
#   'Oliver Cromwell',
#   'retrobrint',
#   'Tanansamen',
#   'AlfÃ©siÃ¨s',
#   'Toormihauk',
#   'via rig',
#   'place of wall',
#   'milrewave milrewave milrewave',
#   'good sumptus',
#   'Wolff Miller',
#   'suroulal force',
#   'Tower treks',
#   "The Adam's Full of Everything",
#   'trigger',
#   'Event',
#   'Reslau of the Sixteen Books',
#   'The Believer',
#   'event called sevent',
#   'spoiled glass',
#   'Saturn',
#   'Jerusalem the Conqueror',
#   'Tachicago',
#   'The Terminator',
#   'Cambodia',
#   'straight horror',
#   'The First Pants',
#   'the Rats',
#   'Humanine Evolution',
#   'Hallerjean dragon',
#   'hard writing',
#   'event',
#   'Tennis War',
#   'Endored the Door',
#   'theory of mystery',
#   'Trevor Ecole',
#   'The Ferocitas',
#   'history of events',
#   'Adam and Eve',
#   "sendis' offense",
#   'Therism',
#   'Tann Lader Adventure',
#   'Chroma Circle',
#   'Tanzim',
#   'avohate',
#   'The last daily shelter',
#   'Calvarac',
#   'The Divided Bob',
#   'funeral',
#   'Event of might',
#   'Intolerance',
#   'Rattletech',
#   'TAX',
#   'The Blue Lower Ons',
#   'civilization',
#   'primitivex',
#   'Haplosso',
#   'The Mathematical Months',
#   'Battle of Cworld Serpent',
#   'historical events for the historical events',
#   'Gratianism',
#   'Execution of the Presidents',
#   'cremation',
#   'King',
#   'Death Day',
#   'in a fever',
#   'Hero',
#   'dualism',
#   'marathon',
#   'the stile stile',
#   'The Best of Munich and Martyr',
#   'Therapeutic principle',
#   'Fudehaman',
#   'two-acceleration relation',
#   'The Cynom',
#   'Slight occuring cross-protest in aviation',
#   'Marlake',
#   'pity of night',
#   'Oursours',
#   'Iin Sligtig',
#   'hearing',
#   'Tetrarchicamandemia',
#   'The Return of the King',
#   'The Chronicles of Wyffy Gorgo?',
#   'The Rules of Rules of Rules',
#   'Sydney Nichols',
#   'trope',
#   'hearing hearing',
#   'preprepioblem',
#   'Remarkable Absence',
#   'Electroenery',
#   "Jacobald's Event",
#   'Marco the playoff',
#   'Old Event',
#   'The Four Planes',
#   'generation creation',
#   'Concert of Managers',
#   'mizler upon the child',
#   'Testification',
#   'Temporal Taste Inorganization',
#   'Second Thunderbolt Wheel',
#   'Milton Friedman',
#   'Jizz al Rasicric Ferguson',
#   'ancient Greece',
#   'Hrathe Ofter',
#   'Clouds events',
#   'Toversity',
#   'The Untold Brain',
#   'Hero Wildon',
#   'natural disaster',
#   'Athens',
#   'Fullman',
#   'Traactatus',
#   'Sabri and Sabri',
#   'time',
#   'WobFoot',
#   'Acting Pony Tactics',
#   'Oligorrok',
#   'herch',
#   'Richie',
#   'TBA Herning',
#   'Triton Personality',
#   'Daymord spider',
#   'January 20',
#   'extorted farming',
#   'event',
#   'Time To discover',
#   'Chun,angadi',
#   'Trehomon',
#   'Ruble Athens',
#   'Object issue',
#   'Herstories',
#   'Incidental troubles',
#   'Battlebooks',
#   "extraliam's unfactual emergence of the public",
#   'human mind',
#   'Walther Valinge',
#   'Cosmological Data International Calling and Datainformation',
#   'Ultra Violin',
#   'Triges) The Triges',
#   'Ptolemy',
#   'allegory',
#   'Mishna Moday',
#   'May Review',
#   'Olym Whisale 210',
#   'the Lookout Technology',
#   'Upriring in the Upriring after the Spriring',
#   'Blumbole',
#   'The True Brisk',
#   'hegemony',
#   'self-love',
#   'TSA',
#   'erotic battles',
#   'The Merry Wives',
#   'Tel Aviv University',
#   'The Secret Services',
#   'Vaging',
#   'Meditation of Meditation by Christ',
#   'Mengite',
#   'David Cameron',
#   'neoplatonism',
#   'Time',
#   'holotustoculus inum',
#   'One Million Annuals',
#   'hit pipe pipe',
#   'Dannyrrida',
#   'Taltestyne',
#   "Freeman's Rank",
#   'Flash scene',
#   'call coherence',
#   "Tab O' Division II",
#   'Shia Jin',
#   'the Battle of Military Burghs',
#   'Demo Som',
#   'Change master',
#   'Judaism',
#   'Exse',
#   'Edgar Allan Poe',
#   'Corgas Cymru',
#   'Molly man',
#   'Scots and Keys',
#   'British philosophy',
#   'Toasia',
#   'time:season 2 of time',
#   'nycente',
#   'The Claims Of Luck',
#   'Spanish Civil War',
#   'Taki osh event',
#   'alter-event current',
#   'photo-filming',
#   "Hitchhiker's Guide To The Galaxy",
#   'Telital assassination',
#   'Defaminism',
#   'Huarlau',
#   'Paral Captain and Attention',
#   'icing',
#   'Markotic',
#   'Heinrich Gauthier',
#   'geodetic geodetic geodetic',
#   'dualism',
#   'Prime Minister of the United Kingdom',
#   'Silverwark',
#   'Viollepponence factor',
#   'Attraction',
#   'The Aviators',
#   'Crlp automobile',
#   'Event Climbing',
#   'The Horoughbourhood',
#   'Sexology',
#   'Russian Revolution of 1917',
#   'Event of Cliffs and Cliffs',
#   'chronography',
#   'William Blake',
#   'nodemic',
#   'terrorism',
#   'Culpritate',
#   'Tracket Prisoner',
#   'Hop-100',
#   'RammatÃ¤vÃ¤tson',
#   'Hangig',
#   'Indian Jihad',
#   'The Block Broker',
#   'Time Machine',
#   'Tersaballa',
#   'Event Event',
#   'tarifvan',
#   'Tarantoku',
#   'Scottish British',
#   'holiday holiday',
#   'Heror of Heroes',
#   '11 Events',
#   'Gallatin',
#   "Slip o' the second cross",
#   'Caul the event',
#   'The Forbes',
#   'The Danger Effect',
#   'Cadillac',
#   'One Brother God Of The Death of Every Sindre',
#   'event in the event',
#   'truscola',
#   'sciutinasy',
#   'Hap',
#   'Autocities and the event footies',
#   'Strategoid',
#   'win in memory',
#   'Serap',
#   'happiness',
#   'Middle Eastern Mormonism',
#   'Time',
#   'happiness',
#   'by fire',
#   'Oblique Meditation',
#   'felicity',
#   'time puch',
#   'Ring',
#   'time oscillation',
#   'Dermetic-Delmetic Arbhitht',
#   'Christbad dinner',
#   'Motion fixture',
#   'Ominouca',
#   'Twelve Wands of the World',
#   'Althaltisans',
#   'Salt Decorated Territory',
#   'technocomputer',
#   'Tempo Ostart',
#   'The Bell Toll Toll',
#   'da capita',
#   'Napalaranda',
#   'Goodness and value theory#Goodness and value theory',
#   'worklibgside',
#   'Teen Lade',
#   'Infonmediator Source',
#   'Atomos',
#   'Cobustion',
#   'theismic religion',
#   'Action solely reverse.',
#   'human norms',
#   'Deseret Freedom',
#   "Hallen's spider",
#   'The Men from Hell',
#   'incialism',
#   'Madesoldery travel',
#   'Brian Green',
#   'habens',
#   'Ketouth Efent',
#   'TAT ATS',
#   'Orion',
#   '13',
#   'Csmastianism',
#   'Home Glore',
#   'Karma Wosha',
#   'The Triumph of the Regens Great Mass',
#   'Trident of Delibarre, South Asia',
#   'Trems',
#   'God Embellishing Strong',
#   'BENES',
#   'The Event Called Ultimate Kind',
#   'Kurthushen',
#   'Insitute of Religion',
#   'The Ancient Greek the Ancient Greek',
#   'The Fountains',
#   'Drache',
#   'Relation of Vingegt',
#   'Afternoon and Inland the Event',
#   'Rilkert the murder',
#   'beating',
#   "Henry's drone",
#   'Refactor',
#   'sliug',
#   'Masochism',
#   'Stan Get',
#   'Crutation',
#   'leaptstage',
#   'Event-Called Added Cemetery',
#   'Gody',
#   'Motivation',
#   'cauld bwisg',
#   'Vendian',
#   'collective sLave conduction',
#   'hit attack',
#   'End of Days',
#   'pore stars',
#   'freak',
#   'The Rallies',
#   'crucifixion',
#   'Hercules',
#   "Eighnat O'Connor",
#   'Agathodinylate',
#   'Halle-Sobiet Rites',
#   'nomination',
#   'Chapterhouse of Arms of God',
#   'Rogues Francisco Bicco',
#   'High Hypoxic Reproductive Hypoxicity',
#   'Falcon',
#   'Vesus',
#   'multitude measurement#Iits',
#   'Full representation of the problems of nature',
#   "The Man Who Wasn't There",
#   'Jack and Relieve',
#   'self-regeneration',
#   'Event Called Shell',
#   'Event book',
#   'H-H-2/V',
#   'Micago',
#   'Teenis Populaire',
#   'Tsuturi',
#   'fiasco center',
#   'Walloon Prince',
#   'Jiver',
#   'Lugene Morte',
#   'pickup',
#   'He Supdam Hiltory',
#   'Way of the World',
#   'history of Ancient Greece',
#   'event call',
#   'Virginia Demolition',
#   'sexism',
#   'Redeficiency',
#   'warpip',
#   '26 March',
#   'biinning',
#   'Sheol',
#   'The Answer',
#   'TÃ«tros peoples',
#   'welfart',
#   'Texas State University',
#   'The Tertiary trilogy',
#   'Net Cartrodge',
#   'Autocross_Autocross_',
#   'Alfiso II of Provence',
#   'Event Called College',
#   'Temptation',
#   'Origin of Religion',
#   'Daniel',
#   'Hashish',
#   'Srake',
#   'Triton triton',
#   'Raining driver',
#   'Strength of Rights',
#   'Hop Darkening',
#   'Event Called Combat Told Bills',
#   'Warner Trotsclass',
#   'Hall of Darkness',
#   'Billy and The Deapor',
#   'tension',
#   'the Redeemer',
#   'Tu neogham',
#   'Druomos',
#   'Creature of Wachitaka',
#   'Gliding',
#   'beatspectence',
#   'axiomatic theory',
#   "Cleveland's development",
#   'hectarevolt',
#   'Outer Cannon',
#   'Crusader voting',
#   'Universal Decision Services',
#   'Harlan the Bat',
#   "Rafbers' theorem",
#   'Rashi',
#   "The Gathering's Nation",
#   'Terra Department',
#   'Otrari',
#   'Tjadernine',
#   'hourd',
#   'Principia Maliboa',
#   'Carbon dioxide sinrate',
#   'Cleveland',
#   'the transformation',
#   'Gales Gales',
#   'tortorum',
#   'Henry and Sydney Hall',
#   'Mail poll#Mail Poll mail poll',
#   'Hunai',
#   'denier',
#   'Fitni wanding',
#   'Darwin Fluer',
#   'Theopology',
#   'The True Golden Slash',
#   'Ludwig von Mises',
#   'FireWiek',
#   'Direction Risk',
#   'Happiness in Jesus',
#   'Tim Ward',
#   'Theodor the architecture',
#   'Flash',
#   'One Tie Up',
#   'The Furnace',
#   'The Beatles',
#   'Pappis',
#   "Blizzard's Angel",
#   "Chaidin's chaidin's chaidin-spice",
#   'big bang',
#   'dirdred',
#   'The Big Sorrow',
#   'Hutshitse',
#   'Outer order',
#   'whole-anticipity',
#   'V-therry',
#   'Brown up of the Brown',
#   'King Modulation',
#   'United States Democratic Progress',
#   'The Events',
#   'Fat Elephant',
#   "Clerm's Alderman",
#   'holiday',
#   'Deutsche Bahn',
#   'Caundate',
#   'event',
#   'Futurama',
#   'The Other Genesis',
#   'Tergerry Satir',
#   'Chronobus',
#   'Sacramented Offensive Test',
#   'Transfer of the Vehicles',
#   'Crucifixion',
#   'delioration',
#   'Terribology',
#   'Slug Ref',
#   'the Revenge',
#   'nick',
#   'the Year Full Festival',
#   'heterotroph',
#   'The Hell of the Heart',
#   'trome',
#   'Sank George',
#   'Malta',
#   'Grand Duchy of Literature',
#   'Blackheath Veterinary Doctrine',
#   'Billy Boy Boy',
#   'non-placated language',
#   'prehistoric schism',
#   'Ventrata',
#   'Ramsey Jansen',
#   'crude oil',
#   'Death',
#   'Terry Remark',
#   'Fire extinguisher',
#   'Extraterrestrial Freedom',
#   'school',
#   'War on the Nature of the Death of the Spirit',
#   'Trime Metamorphism',
#   'Campaign Raid Torch',
#   'historical narrative',
#   'singleton',
#   'John F. Kennedy Government',
#   'Cloyd the Channel',
#   'agripsatos',
#   'the event',
#   'Holiday at a Dom del event',
#   'Golden Hull',
#   'Synapse',
#   'Gratis#Gratis_gratis',
#   'Doi Bidar',
#   'Call of Cohenna',
#   'Kiwipeke Amaloka',
#   'cortaision problem',
#   'A Half Those Events',
#   'The Functions of The Functions',
#   'prisebbello',
#   'American American American american american',
#   'The event called a final event',
#   'Nazi Gerryhahl v. Nazi Gerryhahl',
#   'sinoana',
#   'The Guwhrvahth Factor',
#   'Tokyo',
#   'Gunniweg',
#   'Time',
#   'history of military history',
#   'delicate',
#   'history of ancient Egypt',
#   'Toronto',
#   'Iloration',
#   'Dyarsa',
#   'Task Force 2000',
#   'Tazit dos Incenses',
#   'supment vulnerability',
#   'the men who murdered him',
#   'Time-Diloids',
#   "Aliza's Aliza",
#   'Slippery Bob',
#   'Terrie Smeal',
#   'The Secret Hospital',
#   'Storms and Triples',
#   'turn of the event',
#   'Batana Batana',
#   'sifting around the emergence',
#   'Sillela',
#   'Skeldular skuldule',
#   'ridock',
#   'climbing plan',
#   'Cartesian Cartesianism',
#   'the Hitler',
#   'United States Democratic Presidential Party',
#   'haggadah',
#   'event called a home',
#   'event horizon',
#   'Worldwide being',
#   'Wikipedia-Electronic_Arts',
#   'Killer theorem',
#   'Tertiary traperstrate',
#   "Capel Gunn'n'",
#   'Robin Hood',
#   'The Independent Demonstration',
#   'Tau-Nii Mai',
#   "Stormore's Game",
#   'herlingron',
#   'United Poonage',
#   'Vengeance',
#   'Termunus',
#   'Hiang Hin',
#   'momotion theory',
#   'Ineralary Development',
#   'drio drio',
#   'nightmaring',
#   'Howthouse founders',
#   'Odahuro',
#   'Christs which portrayed the worship of God',
#   'Event',
#   'Rumsay',
#   'Paul II the Conqueror',
#   'Event Camel',
#   'Casey the Dan',
#   'strabo',
#   'Traaistes',
#   "Blocken's dawn",
#   'Trotsky',
#   'Tannever Underground',
#   "Bletchley's Flyer",
#   'tolerance',
#   'Trapeze',
#   'Four Frames',
#   "Madernis' nasty pass",
#   'Turn',
#   'torsion torsion',
#   'Liberty MeanFama',
#   'pre-preprepresentation',
#   'Event in the Council',
#   'Strange Bomb',
#   'Tordicles',
#   'Sheor',
#   'stutter disease',
#   'Troig Fast Forward',
#   'Contraception',
#   "Tremor's personality",
#   'Terrology of heroeses',
#   'Eliot',
#   'moses',
#   'pretender',
#   'Habakkuk',
#   'Lusa Yates',
#   'Torup',
#   'Bondi congregation',
#   'Northern Sathletis',
#   'total event',
#   'interrogation',
#   'Call of Cthulhu',
#   'Hercule Planck',
#   'Slokh the veil',
#   'negotiation',
#   'eruba',
#   'Dark Colours',
#   'Event Called Rise and Fall of Man Patients',
#   'The Red Sangate',
#   'Axbitt J. Joseph Joseph',
#   'the decision',
#   'Junkochev',
#   'Voyage of the Voyage of the Block',
#   'In vivo',
#   'savenger',
#   'Oanah',
#   'herald',
#   'reformation',
#   'Apprented Events',
#   'Dirac',
#   'help desk',
#   'time dull court',
#   'Divinity Game',
#   'event to the last event',
#   'Artifects',
#   'Hawaiian events',
#   '11 Man',
#   'Horizon event',
#   'The Event Called Ar Ar Ar-Ar Arrar',
#   "Jehovah's Witnesses",
#   'Halstock Marketing',
#   'The Crime of Light',
#   'World Total Hit 120',
#   'Fave action',
#   'Gamalteca',
#   'Tranniniana memorial',
#   'Event Cosmice',
#   'record of the same type',
#   'event compartment',
#   'Descartes',
#   'Event Called Events Cents Behind',
#   'neodism',
#   'the Rong',
#   'Temple is not followed',
#   'Bandle of Nature',
#   'Pappy Boy',
#   'Pigding',
#   'meritocracy',
#   "Flowers' event",
#   'heroes of Constantinople',
#   'Thomas Aquinas',
#   'Great Learning',
#   'intertemperative moastic theory',
#   'Hillywill',
#   'trend',
#   'Frontier',
#   'martyr',
#   'Energetics',
#   'crade',
#   'Mazda',
#   'Transformation Limitations',
#   'United States terrorism',
#   'Exclame Home',
#   'Wlades of Fordsworth',
#   'Event of Magle',
#   'football',
#   'event theory',
#   'fiction',
#   'Conspiracy theory',
#   'Platu Munihiro',
#   'Salt Cracking Case',
#   'the Dragon Brute Race',
#   'Brasseri Cataldg',
#   'Consans',
#   'Salian Islam',
#   'Tremplarence',
#   'Celisticism',
#   'himtory',
#   'historical events',
#   'Thing on the March',
#   'Tlemming',
#   'hands-on-hand',
#   'Atrachoman=origin',
#   'moetium',
#   "GÃ¶del's post-tertiary mythology",
#   'PrGe for hip hop',
#   'Clouds of Dogs'],
#  'http://schema.org/Intangible': ['intermeter',
#   'supersonsums',
#   'aftral',
#   'pravis',
#   'operational land',
#   'memory control',
#   'syntnesis',
#   'Formalism',
#   'good characteristics',
#   'mouthshops',
#   'child confrontation',
#   'as descriptive',
#   'theory of divides',
#   'decidence',
#   'division',
#   'ross',
#   'song',
#   'nuclear fusion',
#   'concept, antipolisism',
#   'athletics',
#   "mashed's mashed",
#   'concept and profession',
#   'idea',
#   'creationism',
#   'dictitionaries',
#   'nonviolence',
#   'concept descent',
#   'collateral concepts',
#   'inlectious',
#   'goal',
#   'gadget',
#   'hyposia',
#   'concept function',
#   'concept law',
#   'temporary approach',
#   'confixional care',
#   'sweat',
#   'data compression',
#   'lawyers',
#   '&quot;for all&quot;',
#   'xenophane',
#   'Calling_ergods',
#   'concept meaning',
#   'international model',
#   'action compendium',
#   'conbect',
#   'emotion',
#   'melander',
#   'androclicular virus',
#   'concept associativity',
#   'auxiliaries',
#   'class structure',
#   'competence',
#   'despatch',
#   'concept lability',
#   'muxilation',
#   'concept-specific concepts survey',
#   'Luca and Los Altar',
#   'aptitums',
#   'contribution',
#   'MÃ©tis',
#   'concept of set theory',
#   'Iteration theory',
#   'delicate',
#   'rifterite',
#   'climbing in regular delivery',
#   'concepts',
#   'political freedom',
#   'Called Questions Called Questions)',
#   'trase',
#   'momentum',
#   'HQ',
#   'cranon',
#   'finite',
#   'involuntary suecus',
#   'freedmen',
#   'hypocalculus',
#   'naturalism',
#   'fiction',
#   'mucous mucous',
#   'buttercutter',
#   'Howthouse',
#   'association',
#   'ivor of Orion',
#   'monopopopop pop',
#   'continued education',
#   'concept called concept theory',
#   'mixsick',
#   'war correction',
#   'concept called its concept',
#   'concept lab call',
#   'equation',
#   'extraligy',
#   'action sound',
#   'sanity',
#   'nomination',
#   'chemotherapeutic activity',
#   'crucifixotomy',
#   'coh-chain control',
#   'counter-counter counter criticism',
#   'comcept call',
#   'unruly and chronicles',
#   'semantic method',
#   'contept call',
#   'individual sovereignty',
#   'hop-head',
#   'Vooroom',
#   'emotion',
#   'hearing',
#   'macro',
#   'dualism',
#   'Mithah',
#   'concept encounter',
#   'Infonmediate Infonmediate',
#   'emered shot',
#   'concept argument',
#   'aphodicism',
#   'commettator',
#   'torsion',
#   'justification',
#   'confionalism',
#   'consept-decision',
#   'transformation',
#   'coalescence',
#   'intelligent design',
#   'geographic area',
#   'hilting pressure',
#   'cooned dark dark dark dark dark dark dark dark arrangement',
#   'edition theory',
#   'counterculture',
#   'self-love',
#   'mutuation',
#   'negative boundary boundary',
#   'von Neumann propagation',
#   'widership',
#   'concept of unconcept',
#   "Freeman's Gate",
#   'vitamin D',
#   'tensor call',
#   'resistivism',
#   'quantosomical concept',
#   'confept',
#   'called concept',
#   'hegemeneak',
#   'handjuf',
#   'physics',
#   'logocarditor',
#   'absolute parameters',
#   'concept called a concept theory',
#   'illustration',
#   'associative',
#   'theory of everything',
#   'conveption',
#   'amtimim',
#   'singularity',
#   'antiparanoia',
#   'midiag',
#   'concept of basic topics',
#   'aploisome',
#   'beliuf',
#   '&quot;four&quot;.',
#   'tide',
#   'waste carrier',
#   'mount',
#   'mosasairlith',
#   'ethic of due confidence',
#   'asteroid',
#   'labour use',
#   'community',
#   'grams',
#   'absolute minimum',
#   'intention',
#   'chambered envelope',
#   'demographics',
#   'electronic',
#   'end-to-end',
#   'Habbanized',
#   'hermetic',
#   'pointing art',
#   'universal intelligence',
#   'Georgia',
#   'the rational numbers',
#   'common standardization algorithm',
#   'concept of sale',
#   'rubber',
#   'geographical geographical agrids',
#   'intertetrator',
#   'verrimrim',
#   'fatty action',
#   'Contracept',
#   'morhem',
#   'viable',
#   'laborum channeling',
#   'comprehensive call',
#   'MÃ©rÃ©',
#   'pragmatism',
#   'inductive therapy',
#   'nickel',
#   'pity of pity',
#   'ending',
#   'altogetheron',
#   'derivative',
#   'proboscism',
#   'emotion',
#   'set of commutities',
#   "''flat domain''",
#   'nyhon',
#   'weak weak',
#   'Conveption',
#   'Differentiation#Equivocalization and process',
#   'common concept',
#   'to burden',
#   'predicate',
#   'geometric',
#   'law',
#   'biogeography',
#   '&quot;divoscence&quot;',
#   'Control',
#   'negative and non-negative negatives',
#   'sacramented smell',
#   'historical Statistical Spaces',
#   'cite criminal',
#   'atomic self-absorption',
#   'quaternion',
#   'future society',
#   'madage',
#   'comductive cell',
#   'conceptual professionalism',
#   'probosc',
#   'andromedal called andromedal',
#   'hebeisis',
#   'virtuolem walking',
#   'conceptualization',
#   'assembly law',
#   'concept algorithm',
#   "concept's decomposition",
#   'context spreading',
#   'figure of figures of figures',
#   'rabbit',
#   'limitation',
#   'Sri/Sri Ley called Concept of Conception relations',
#   'economic history',
#   'inducation',
#   'direct-to-use memory',
#   'hard work',
#   'darwinism',
#   'concept of quantum mechanics',
#   'empirical value',
#   'dice',
#   'independent state',
#   'Division',
#   'concept of anumism',
#   'herlinicic herlinicic herlinicic herlinicic herlinicic',
#   'agrobability',
#   'periodic taboo theory',
#   "KÏ\x80'liÃª nutmemes steel",
#   'persuasiomism',
#   'di-ule-di-ule',
#   'concept of supernova',
#   'consciousness',
#   'nightmarishmithside',
#   'factitious conserver',
#   'aptition',
#   'transonination',
#   'conformation',
#   'convex solid',
#   'secret Secret',
#   'conserver',
#   'tennis point',
#   'set',
#   'concept receiver',
#   'combat',
#   "'ever-mentioned derivation method",
#   'iteraction/primitive memory',
#   'property type',
#   'statutory law',
#   'process',
#   'apetheria',
#   'call parcel',
#   'concept map',
#   'monopoly',
#   'cement',
#   'Gaothtica',
#   'treatment',
#   'minrawalization',
#   'function',
#   'non-manifestation',
#   'reverse marker',
#   'Concept of the arts',
#   'concept of design',
#   'modernism',
#   'mammal',
#   'metamathematics',
#   'dilution',
#   'rose',
#   'microbeology',
#   'concept called concept theory',
#   'concept theory',
#   'involutement',
#   'allal',
#   'retional motion',
#   'homotoxy',
#   'axiom',
#   'Kalled George Greenleaf',
#   'concept of concept',
#   'contradiction',
#   'consept',
#   'Concept of something',
#   'concept call',
#   'belief',
#   'equivivistism',
#   'holotophy',
#   'distilleries',
#   'counterfactual counterpart',
#   'Galen galen',
#   'concept of mythology',
#   'machine language',
#   'infrared',
#   'principle of consciousness',
#   'nonsense after a limbic',
#   'Descache',
#   'study of study',
#   'Defemstion',
#   'poece',
#   'climting',
#   'universal prime identity',
#   'non-regenerative marking',
#   'concept Virus',
#   'function call',
#   'concept',
#   'mental ics property',
#   'Dataset',
#   'conceptation',
#   'cosmological conjecture',
#   'acromym',
#   'reunitation',
#   'reality problem',
#   'zirconium',
#   'induction',
#   'dualism',
#   'class',
#   'Catholicism',
#   'insumin',
#   'euclidean solid',
#   'bons sui',
#   'synonym',
#   'probability',
#   'concept of aogons',
#   'turn availability',
#   'atabass',
#   'socialism',
#   'retarded sadduct',
#   'regunature',
#   'tolerona',
#   'morality',
#   'rule of law',
#   'concept of art',
#   'propositional impersonification',
#   'leaf',
#   'Favour Paradox',
#   'pacifus',
#   'conceptualization',
#   'asteroid',
#   'Stoicism',
#   'muniere',
#   'atom',
#   'eating',
#   'tichehood',
#   'measure theory',
#   'concept theory',
#   'sounding effect',
#   'concept of arms',
#   'incongenitalism',
#   'concept of major major',
#   'concept necessity',
#   'method of determining the method',
#   'concept alignment',
#   'antinoupepipolis',
#   'convertion',
#   'monophysitalism',
#   'Conveptional supernova',
#   'elementary particle',
#   'perfume',
#   'composition_',
#   'cognomen',
#   'double slot',
#   'wall',
#   'holosynthesis',
#   'call bloc',
#   'truscology',
#   'civilisation',
#   'call controls',
#   'gear',
#   'footipi.moment',
#   'commeter',
#   'transform transform transform transform',
#   'abelian',
#   'beauty',
#   'balance',
#   'concept-vector space',
#   'psychic',
#   'criticism',
#   'vortrall',
#   'motion',
#   'hermetic cross-curved design',
#   'paining',
#   'properties',
#   'semantics',
#   'competitive evolution',
#   'concept epic',
#   'convertion',
#   'Danmer Danmer Danmer Danmer Danmer',
#   'evolution',
#   'Central Theory of Concepts',
#   'concept and analysis',
#   'being',
#   'conception',
#   'Lucky Ducky',
# ...
#   'Gabriele Lapracida',
#   'Darka, Darka',
#   'Jed al-Garmani',
#   'Oceanoglidae',
#   'Carthage',
#   'Gester Adams',
#   'Mignon',
#   'Patricia ad Dase',
#   'Jive Beatty',
#   'Euwoen',
#   'Jeanne Deyrerge',
#   'H.G. Wells',
#   'Apple Computer',
#   'Wolf Wolf',
#   'The Fictional Man',
#   'Great Granada',
#   'stompback',
#   "Halley's Modern Life",
#   'Serneye Cowboy',
#   'Iron Purr',
#   'Edward Fox (November)',
#   'Moon',
#   'Hadwan',
#   'Jarret Paysor',
#   'Golding Stone',
#   'Margoline Ducas',
#   'Deketon',
#   'Byrne',
#   'Union Island',
#   'Don Budget',
#   'Dory Dory Dory',
#   'Shreenscam',
#   'Bas Bas',
#   'George Jackson',
#   'Rosa Luis GerÅ\x91a',
#   'Urafuci, Myltona',
#   'Alfred Herricks Entity Browse',
#   'Valdez',
#   'Deathmatch',
#   'Graeces',
#   'Second Entity Republic',
#   'William Browning',
#   'Plamers',
#   'Strathern Borough of Lincoln',
#   'Larry Larry',
#   'Actor',
#   'Madeira',
#   'Kchenele',
#   'Flight 1239',
#   'Graham Graham',
#   'Henry Goard',
#   'Darleen',
#   'Detroit Tigs',
#   'Bo Aquarapaci',
#   "Chardin's Statue",
#   'Jane coma',
#   'Mechanical Entity',
#   'Atholnes',
#   'Malta',
#   'Kiwapeki Amamoto',
#   'Hiliola',
#   'Yogomo Fry',
#   'Marco the Conqueror',
#   'Jack',
#   'Ambassador Bucomet',
#   'Dirnealog',
#   'Whitaker mall',
#   'Carl Friedrich Phulmann',
#   'Chromobue',
#   'Champlain Fantasy',
#   'Jachis M. Nachman',
#   'The Animals',
#   'Eros',
#   'CIMA Delaunal',
#   'Elof Nydune',
#   'Inspector Gomez',
#   'Saud Reifer',
#   'Samuel Johnson',
#   'Victorio Polegri',
#   'Hanriet Bartender',
#   'Stimsberger',
#   'Paulus-Nationalistis',
#   'Druene',
#   'Ursula Reborn',
#   'Ramsar',
#   'Drunkorder',
#   'H. G. Wells',
#   'The Trilogy',
#   'Scrooge',
#   'Tinker Bridge',
#   'Peter Obderman',
#   'Cronun',
#   'J.H. Lennon',
#   'Darlington Omega',
#   'Erysus',
#   'The Clansman',
#   'Poaceae',
#   'Gearlock',
#   'Marilyn Mines',
#   'Javier Douglas',
#   'Cent Cono Cono',
#   'Snowmorkets',
#   'Adei',
#   'Fictional illustrator',
#   'Al Gorgon',
#   'Dostoevsky',
#   'Amerdown Creek',
#   'Entity The Entity',
#   'Son of Mad Gowe',
#   'Clermont',
#   'Welson Welson',
#   'Roland Bergher',
#   'Kekiharo',
#   'MaBD',
#   'Leor Rowland',
#   'Blizzard of Trent',
#   'Jai',
#   'Sunenesus',
#   'Marriage and Return',
#   'Helena Priso',
#   'Fictional theme tune',
#   'Modern Greek',
#   'Vom Mandelen',
#   'Arrick Burgess',
#   'Cune',
#   'Spananda',
#   'C. M. Schulz',
#   'Netela Park',
#   'Ombundum',
#   'Firth Entity',
#   'Asbertus',
#   'Drono',
#   'Madeus Enabus',
#   'Fictional Fiction Laws',
#   'Silvio Barley',
#   'Gemariek Michelet',
#   'Nilly Clibson',
#   'Kai Au, Jigor.',
#   'Sordillonak',
#   'Quota:Unity The Birds',
#   'Sammy Ball',
#   'GormÃ¼n',
#   'Fictional Crowd',
#   'Howard Udendsney',
#   'June 9',
#   'Lorie Sound',
#   'Lin Parder',
#   'Father Baglio',
#   'Jerse Long',
#   'Hawusa Puri Moratta',
#   'Mark Tweed',
#   'Garaldi of Aptidistism',
#   'Saturday Night Live',
#   'Project Gutenberg',
#   'Clouds',
#   'Athanasius',
#   'Slide &quot;Slide&quot;',
#   'Muluo',
#   'Tovirsoth',
#   'Surrenega',
#   'Blehmberg',
#   'Warner Skalinga',
#   'The Miser',
#   'Corgasmener',
#   'Henry Villiers, 1st Baron Villiers',
#   'Westboro Concord, Texas',
#   'Eddie (Christie) The Christie',
#   'Dr. Dre',
#   'Watcher Oscar',
#   'Else',
#   'Tanansas',
#   'Harlay the Bat',
#   'Begendi{{NorseMythology}}',
#   'Helen',
#   'CSGAU-G',
#   'Luke the North',
#   'The Animated Serum',
#   'Smorthrone Saturday',
#   'Blizzard of Priscis',
#   'Brano Dimarkovsky',
#   'Howard Clayton, 1st Earl of Devon',
#   'A Range of Gods',
#   'Shuhanbara',
#   'Emhemera Omega',
#   'Reslanto',
#   'Celin Kane',
#   'Nobcomer',
#   'Gabolein',
#   'Balliel',
#   'John Tudor',
#   'George Orwell',
#   'Shafier Gural',
#   'The Screwtape Letters',
#   'Salomon wheeler',
#   'Fictional Date The Date of January 1',
#   'The Tomb',
#   'Eamlest Hambledge',
#   'Adverse Dictionary of Computing',
#   'Fictional Batch Society of Fiction',
#   'Barka Bat',
#   'Howehead',
#   'Wu',
#   'Jack Lillida',
#   "St. Mary's Island",
#   'Grevian colonization of Antigonia',
#   'Frankenstein',
#   'Onononono',
#   'Fab named Fab. David',
#   'Travmatis',
#   'Unson',
#   'God Emperor of Tartu',
#   'Primulus',
#   'Chicago Celebrity',
#   'Warner Trot',
#   'Ken Bath',
#   'Gunner Pleasant',
#   'Sexwanker',
#   'Superkondra',
#   'Darwin Flears',
#   'Elizabeth Patterson',
#   'Trekkiet',
#   'Fudeh',
#   'D.G. Downs',
#   'Sid MacMahan',
#   'Bandido',
#   'Harlan Harlan',
#   'Mara Statute',
#   'Sabes',
#   'Barnee',
#   'Nanne Soteney',
#   'Mahabara Bear',
#   'PANPAN',
#   'Mariana of Ireland',
#   'Sumerhand',
#   'Holiday Hiliday',
#   'Myleleadhole',
#   'Ilorah Nasheh)',
#   'Cairner',
#   'Driscola, Queen of Scots',
#   'Descachers',
#   'Bruce Western',
#   'Crasserbach',
#   'Homer',
#   'Megbata',
#   'Exarata',
#   'Ward Agriene',
#   'Doom underway',
#   'Led Zeppelin',
#   'Ceraria',
#   'Deadlock',
#   'Barana Zapanella',
#   'Ultra Thurmanova',
#   'Stonehenkel',
#   'Idi Flovic',
#   'Nativity',
#   'Clennaa the Ottoman',
#   'Sydney Stadium',
#   'Sensorulus',
#   'H-H-2/V',
#   'The Sky Publication',
#   'Heror of Heroes',
#   'Breholding Mat',
#   'Plan de la Democretain',
#   'Yasrar al-Mahammin',
#   'Sri Lanka',
#   'Deuilouris',
#   'Dulls',
#   "Blocken'n' album",
#   'Omni<',
#   'Berthed Friedmann',
#   'Wojciech',
#   'Milton Fiction',
#   'John Mills, 1st Viscount Mills',
#   'ND-S2',
#   'Bolochas',
#   'Mace, Alabama',
#   'Energy',
#   'Ramsey Juliet',
#   'Arnold Sommerfeld',
#   'Russian Albert and Soviet Revolution',
#   'AubarÃ¡n',
#   'FirtiÃ¡n Frogo',
#   'Axbizz Lip After Sardonic',
#   'Ingnors Griffith',
#   'G.S. Woolf',
#   'Rubensen ad Dodd May',
#   'The Flame',
#   'Boulughan',
#   'Wolden Elements Changeled',
#   'Fictional Bureaucracy: Wars of the Wars',
#   'Diablo II',
#   'British Aerospace',
#   'Ashoka Atouraas',
#   'Craneion',
#   'The Swiss Wann',
#   'Bevsree',
#   'Autarashi',
#   'Rohypnos',
#   'Vallej Vallej',
#   'Parsons boy',
#   'Gran Hason',
#   'Arnas Smith',
#   'H. G. Wells',
#   'Fanetto',
#   'Ingo and Three-Net',
#   'Meorsenska on Dork',
#   'Gonicula',
#   'Cuivlagan',
#   'Ulsio Possibly',
#   'Marvin Milling',
#   'Lalleston Magdalena',
#   'Abelauder Hebbel',
#   'Michael Morse',
#   'Fulharroi',
#   'Arthur Berner',
#   'Capel',
#   'Elfqnode',
#   'Robin Wiley',
#   'Seven Days War',
#   'Doras, Doras',
#   'Mac Sava',
#   'Betta',
#   'Furnyasalabararata',
#   'El Tador',
#   'Usinaora',
#   'Diabrosa',
#   'Brasserisk',
#   'Havarlabh',
#   'Walloon Prince',
#   'Carl Selling',
#   'Quentin',
#   'David Bushnell',
#   'Nobel Prize',
#   'Seth Stealey',
#   'Harlawanda',
#   'Uprill in the Eastern Middle East',
#   'Gustave de Lorian Sabato',
#   'Dartes',
#   'Greenwich',
#   'Sally Pope',
#   'Ulrike Leap',
#   'Hiang-Hun',
#   'Kymcharine Kymcharine',
#   'John Locator',
#   'Tennant Tennant',
#   'R.F.R.I.',
#   'John Hope Rose, 1st Viscount Hope',
#   'The Official Monthly',
#   'Short Urrachevd',
#   'William Lord',
#   'Blethrrich Malodon',
#   'Lingaeata',
#   'Grant Wassily Kirkpatrick',
#   'Be Saloon',
#   'Vomovo',
#   'Ayawna',
#   'Arthur Shoemers',
#   "Charles's Daughters of Rat",
#   'Richard Newman',
#   'Slive in Slive',
#   'Bashtowe, Bashtowe',
#   'Babe Ruth',
#   'Leukerver',
#   'Tera sha Kip',
#   'SjÃ¡lz Cobel',
#   'Bruce Dyne',
#   'Brian Pittski Tor',
#   'Naked Nordrim',
#   'QuickTime',
#   'Henry Cudb',
#   'Season 3',
#   'El Bota de Vaguenes',
#   'Shariro',
#   'William James Dadiborhi',
#   'Fictional Anthology',
#   'Oryson Canterbury',
#   'Sri Steeller, Sri Lanka',
#   'Aleis Mendeles',
#   'Woses',
#   'Quennesford Tower',
#   'Bandle',
#   'Buck Morris',
#   'Saracenea',
#   'Lotional Sborming Council',
#   'Csmaster',
#   'Saudert Steel',
#   'Mirá¾\x8dk Finang',
#   'Sreddeck',
#   'Freddin S. Ourd',
#   'Ã\x9aruaiso province, and Orohihi',
#   'Raphael Turner',
#   'Hande-Soghur Entity',
#   'Deadic Baby Boy',
#   'Tremslacht',
#   'Hunties',
#   'Leo Tokanin',
#   'ABF Bhork',
#   'Jack and Jack',
#   'Sugew Always',
#   'Griphed',
#   'Genesis',
#   'Battle of Bad Ringer',
#   'Encyclopaedia Britannica',
#   'Cao-Kiin-Fi',
#   'Mike Watkin',
#   'Wisconsin',
#   'Gallakan Arborissar',
#   'Mike a Gutty',
#   'C. P. Perensen',
#   'Eneladorr',
#   'Dashinkya',
#   'Firan',
#   'Shelda Dave',
#   'A Salien Vine',
#   'Eddie Tourney',
#   'S. Forge',
#   'Walberwocki',
#   'Sin Communications',
#   'S.F. Claus',
#   'Grigg',
#   'Ben Rock',
#   'Sylvia Bingley',
#   'Spinoza',
#   'George Florida',
#   'Werden SalÃ\x9fedie',
#   'Perch',
#   'Presentation',
#   'January 22',
#   'Plato',
#   'Session',
#   'Quaelelelele',
#   'Darrell Page',
#   'Dido',
#   'Spytnik',
#   'dabbati',
#   'S.Q. Kennedy',
#   'Squatsoft Squatsoft',
#   'Technoposposius',
#   'Stabisticus',
#   'Armenia',
#   'Elchahanin',
#   'SB Well',
#   'Sel. Sel Sel',
#   'Kolukama',
#   'Dark Angel',
#   'The Spaceship Planets',
#   'Steve Barker',
#   'Mazan Garofa',
#   'Accessible Entity Name Register',
#   'Aunerst. fictional entity',
#   'Dlois Pourin',
#   'Dupont Zoo',
#   'Michael Chee',
#   'Bethian Bethian',
#   'United States Herring',
#   'Leviticus',
#   'Elson, Oregon',
#   'Cyduheeperrency',
#   'Karlhauer',
#   'Breadtheater Harbor',
#   'Grade Mouse',
#   'Iii',
#   'Bellamy Hill',
#   'Q.e.t.',
#   'Doc Savage',
#   'John Hurt',
#   'Luthia',
#   'John Forber',
#   'Queen Milan',
#   'Thiesnos Arcistro Andresso',
#   'Steve Aolen',
#   'Enrique',
#   'Mega Trok',
#   'Carracci',
#   'Arreste Ungsen',
#   'Star Scandal',
#   'On-Nights City',
#   'Salon Bagbisti',
#   'Netscape',
#   'The Clan Association',
#   'Smirnon Sh. Race',
#   'Papua Nuvertux',
#   'Iphynocephalus',
#   'Hercules',
#   'Khorasan',
#   'Charlub Mudden',
#   'Stevan Jardi',
#   'The Albert Sellers',
#   'Circrethers',
#   'Brosso Bowman',
#   'Michael Lagrans',
#   'Waylon Texas',
#   'Bea-Bea',
#   'Parama Perroma',
#   'Book of Posthumous Kings',
#   'Hope',
#   'Hal Al',
#   'Futua',
#   'Neebu Gaymante',
#   'Edgeware',
#   'Epsilon',
#   'The Book of Entities',
#   'Shiwa',
#   'Edelpem v Myre ab Evelldoor',
#   'Karma Washington',
#   'Stsrega',
#   '1981',
#   'Ptolemy',
#   'BATTLES',
#   'MS-138',
#   'Quinine',
#   'Regulausa Marquesa',
#   'Rillert James',
#   'CSS Code',
#   'Snorfall',
#   'Quickcity',
#   'Shecker',
#   'Brian Bonehuilt',
#   'The Lord of the Rings',
#   'Deacon Hill',
#   'Jubel in the Serpent Moons',
#   'Hrasnod',
#   'Rennar Darylyn',
#   'Cunningham Oberranch',
#   'Ekkara Family',
#   'Mean Time',
#   'Christslensys Corporation',
#   'Red Hat Tower',
#   'Cretan Gulf',
#   'Sri Lankan the Law',
#   'TBA Herning',
#   'Harteme-Semblyment Sand',
#   'Maximum Schwarzenegger',
#   'Tintu-Uui',
#   'The Fictional Ranchers',
#   'Walter W. Murtal',
#   'Tura',
#   'Ameis the Conqueror',
#   'Orchestra',
#   'Time-Lord (AST)',
#   'Djin Lov',
#   'Herwood Hodany',
#   'Fictional Haul',
#   'Chantal',
#   'Pigding Zeg',
#   'Steven Pogton',
#   'Tsutsupei',
#   'Hutsflank',
#   'Han Chen Ken',
#   'Keen Crosberg',
#   'Oso Sioni',
#   'Agripoli',
#   'Prince Prince France of Manager',
#   'to shim emperor',
#   'Draging Born',
#   'Showheads Doctor',
#   'The Velus',
#   'Spectacle Bulletin boarding',
#   'San Diego Zapatero',
#   "IDa, Ida, Ida, Ida'",
#   'Drudentor',
#   'JÃ¡n al Ghaires',
#   'Rosemary Renards',
#   'Ã\x85rdmaÃ°l Ã\x85rdmaÃ°l Ã\x85rdmaatl',
#   'Barry North',
#   "Jehovah's Witnesses",
#   'Berry',
#   'Mount Herson',
#   'Rellibo-PolomÃ\xade Caragelera',
#   'Gargoyles',
#   'Jean-Luc Godard',
#   'Rayber Rayber',
#   'Dean S. Klark',
#   'Enfitt',
#   'Wikinews',
#   'Archis Hotel',
#   'Amis of University',
#   'Suboumasaita',
#   'Blazar Pavin',
#   'S. A F. Thomson',
#   'Pranath',
#   'Sacramento, Colorado',
#   'Brian Brundon',
#   'Wade Palace',
#   'Haddiq',
#   'Farranga',
#   'Jo-the-Inparather',
#   'Fashlands of Prague',
#   'Kris of Dogs',
#   'Tokyo',
#   'Howard Atkinson',
#   'Advertus Sirens',
#   'Fictional Bloomsbury',
#   'Ararsa',
#   'Dame Fuck',
#   'Underamembered Arrows',
#   'Howard Swanson',
#   'Saturn',
#   'Enigma',
#   'Mac Turner',
#   'Salisbus',
#   'GallienDen,Walleton',
#   'Origin Delle Albert',
#   'Much Growth',
#   'Alizah',
#   'Ethiopian JewR',
#   'Freddy Grant',
#   'Juxo',
#   'SS SS Columb',
#   'Ultsa Meyer Meyer',
#   'Atrich banner',
#   'Regenhard Grand Herringberg',
#   'Northern Tewnessee',
#   'Arshparthen',
#   'V-ten',
#   'Archibald Coco',
#   'Branjo WarÄ\x8dÅ\x8da',
#   'Macbeth',
#   'Murato',
#   'S. Adams',
#   'Gou Gou',
#   'Lfrod Sedenbawm',
#   'Ulrier Gulf',
#   'Jill baxley',
#   'Ganes Gear',
#   'Fantasman',
#   'Ruddington Park',
#   'WNDO',
#   'The Police for the Fury',
#   'Idav',
#   'Ed S. Dockerman',
#   'Apple Computer',
#   'Fictional Geographical Society',
#   'Alianz',
#   'John Ireland',
#   'Senator',
#   'Chun,chondu',
#   'Entity of Solitus',
#   'Doggy La Race',
#   'Fetuski',
#   'Fictional Twins',
#   'Umar ibn al-Awfar',
#   'Fictional character',
#   'Marlo Masters',
#   'Bobby Bobby',
#   'Carona',
#   'Vario Distillation',
#   'Ring',
#   'Sigdis',
#   'Phiebe Peare',
#   'Deavor and Right',
#   'Eudmoi',
#   'George Dublin',
#   'The Battle.The Battle',
#   'H.K.D.',
#   'Chrysler',
#   'List of Scots-related topics',
#   'Quicken Piper',
#   'Uan an White',
#   'Jackposse',
#   'Fictional Flags, Fishing &amp; Fishing',
#   'Arram (Dodge) Ovrell',
#   'The Brookers',
#   'Garage Hankers',
#   'Abrahamic regions of Egypt',
#   'Herr Wubbard',
#   'RÃ«ki Ampatei',
#   'Arrock Wilkins',
#   'Brethge',
#   'Set',
#   'Adrenalin',
#   'Bobby Bobby',
#   "Hitchhiker's Guide to the Galaxy",
#   'The Masner',
#   'Edward Lear, 1st Earl Lear',
#   'Giancarlo Aguini',
#   'Cuapabaran',
#   'Conspiracy theory',
#   'S.R.',
#   'Gunning',
#   'Capstone of Fort',
#   'BENES',
#   'Abrayama',
#   'Governor of the Mersian Kings',
#   'Adlan Parford',
#   'Denezel Fredericks, Duke of Saxe-Coburg and Gotha',
#   'Frederick S Sherry',
#   'Athens',
#   'Mulwark entity',
#   'Margoto Margoto',
#   'Autreai',
#   'Howard Sapard',
#   'Kentucky',
#   '2. M. Suzanne',
#   'Papcos',
#   'Crowfootball',
#   'Ettica',
#   'Adin Syda',
#   'Guzman ultimate chief',
#   'Graham Narbon, Duke of Somerset',
#   'Amagiltas',
#   'Arlanga',
#   'Andrea Walton',
#   "Edtu's Gods",
#   'Calculator',
#   'Ben-Tong',
#   'Frytale fiction',
#   'Habakuk',
#   'Eoebir',
#   'Sheran',
#   "'liberty named'",
#   'Lison Hot',
#   'Sloop',
#   'Baton, Dorae',
#   'Swatara Lakit',
#   'E, M. W.',
#   'Fictional conventions',
#   'shildun',
#   'Infoneran',
#   'Steve Blight',
#   'Beyond Babes',
#   'Semi-Hull',
#   'Ascorbius',
#   'Al Harpin',
#   'AbrÃ©sia',
#   'Iteralaria Deodoto',
#   'J.M.Carthyhayes',
#   'GÃ¼dglenn Holdings Hoodings Hoodings',
#   'Jacob D. Smith',
#   'Scott Shopham',
#   'Eric A. Curry',
#   'Napanaram, Myrana',
#   'Enthalpeeg',
#   'Indigy and Metapanka',
#   'Lidsadiod',
#   'Cassia',
#   'Chapman',
#   'Confidence, California',
#   'Rubenson',
#   'Caul Retler',
#   'Saunders',
#   'Dunwin',
#   'Henry Worst Worst, 1st Earl of Dunlop',
#   'Great Lakes',
#   'Berlin',
#   'Marvel Universe',
#   'Mushr',
#   'Gravias',
#   'Saunageris',
#   'Helenworth',
#   'Deece (Deece)',
#   'Henry Fincher',
#   'Zoazoa',
#   'PBK',
#   'Homemouth',
#   'Jerry Babpart',
#   'York',
#   'Mome Or Or No Dome',
#   'D. A. Frynch',
#   'Kurthushenko',
#   'Selly Lousie',
#   'Napsaarose',
#   'Jergen the Jaguar',
#   'Hjaratada, Attacks of Jambatham',
#   'T. Guetta sawringer',
#   'Bronthers Walthing',
#   'The Middle Ages',
#   'San Francisco',
#   'Celaca Flagleo',
#   'Lotter the Lion',
#   'George Davies',
#   'U R A a Hanaman',
#   'Weird Language',
#   'Genesis',
#   'Santa Barbara',
#   'Raltelta',
#   'Adleraule',
#   'The Story of C. S. Lewis',
#   'The Gung-neg',
#   'Arnold Schwarzenegger',
#   'Singapore',
#   'Adulthood',
#   'Duke Nukem 3',
#   'Quintane',
#   'Sansor Sermondo',
#   'Dorge is the Dorge',
#   'Chrome Circus',
#   'Favelace',
#   'Arnon, Lord Temple of Comberland',
#   'Settito',
#   'Sonomanosara',
#   'Narling Sthueless',
#   'Arabal',
#   'Gene Harnes',
#   'Goliath',
#   'Saburnabura',
#   'Robrie Rubrie',
#   'Defanieneb',
#   'Bekkening Software Software Corporation',
#   'Yacq',
#   'Wilfiam Henley',
#   'Kreekondura, Onona',
#   'Bob Dylan',
#   'Mithail Hall',
#   'Storza Satoma',
#   'Hilbert Spencer',
#   'Athens',
#   'Arondada',
#   'Prataganga',
#   'Red',
#   'Billy Buksman',
#   'Ningalo-Takarada.',
#   'Cascadina',
#   'Shiniah',
#   'Star Search',
#   'Consarsar',
#   'Email',
#   'Worldwide beauty',
#   'Sunning Bat',
#   'Stormons',
#   'Concept of Mathematics',
#   'Blorada',
#   'Maughnurth',
#   'Hillallam',
#   'The Aviators',
#   'Maurice Queller',
#   'Pope Leo XIII',
#   'Reymond, Massachusetts',
#   'The Syrian Bird',
#   'ZenÄ\x9bn',
#   'James Wenton',
#   'Slave the Hole',
#   'Dulusverne',
#   'Grande Boillow',
#   'So A Mideast',
#   'Midhan',
#   'Spike',
#   'Chorgangcen',
#   'Delandarte',
#   'Sid Meigh',
#   'Howard Heath',
#   'Four Franks',
#   'Wobcock, Oliver Twoman',
#   'Fictional Fantasy Trilogy',
#   'Jason Leifert',
#   'Arena, Oval',
#   'Stan Getty',
#   'Silverhammer',
#   'Dione',
#   'David Blunty',
#   'Clouds',
#   'H.G. Wells',
#   "Quene's hold",
#   'Marrison Bedun']}

# %%
with open(YAGO_FAKE_ENTITIES_PATH, "w", encoding='utf-8') as fp:
    json.dump(entity_types_to_fake_entities, fp, ensure_ascii=False, indent=4)

# %%
for k, v in yago_qec.items():
    entity_types = yago_qec[k]["entity_types"]
    eligible_fake_entities = list(itertools.chain.from_iterable([entity_types_to_fake_entities[et] for et in entity_types]))
    yago_qec[k]["fake_entities"] = random.sample(eligible_fake_entities, len(yago_qec[k]["entities"]))

# %%
yago_qec['http://schema.org/editor']["fake_entities"]
# Out:
# ['old contrast',
#  'Flasderster',
#  'Motivation',
#  'time',
#  'Compact Disc',
#  'Hermitima',
#  'amphorescents',
#  'Poaceae',
#  'analogue testing',
#  'free motion',
#  'Gratiful Depression',
#  'Death of the Murder',
#  'Jeb Callaghan',
#  'Pritching the Telephone',
#  'product butter',
#  'syntnesis',
#  'Adolf Hitler',
#  'peer-to-peer',
#  'Librevians',
#  'powder',
#  'Callaf',
#  'nuclear arrival',
#  'History of the Americas#History of the Americas',
#  'Vita Crevi',
#  'PPP',
#  'porces',
#  'connectivity',
#  'Agagiwa Thermodynamic',
#  'Russian Russia',
#  'Lecies',
#  'well-worthiness',
#  'Valkyrie',
#  'Tequin',
#  'Tilturgun',
#  'Diemen Betham atatii',
#  'William Wilkinsot Mikhailov',
#  'Don an Award',
#  'Blue Works',
#  'Andromon',
#  'voiceless consonant',
#  'photous',
#  'Connecticut',
#  'Pelry and the Travelsable Works',
#  'the fifth film',
#  'fuzzy fuzzy',
#  'The Southern Participation of the Barbarian',
#  'Compact Disc',
#  'deciding sheet',
#  'Stormsryke',
#  'Service aligning',
#  'equity show',
#  'most buyed organization',
#  'Divinity Divinity',
#  'auteus',
#  "The Adam's Full Work",
#  'The product is called The Product',
#  'nynonon',
#  'Calculations',
#  'Placidy (magic)',
#  'neolithic',
#  'Polygon',
#  'Scottish Bedringa Bedringa',
#  'Direct Array',
#  'The Protector',
#  'power printing',
#  'switching',
#  'CSIA',
#  'pAppet',
#  'reality test',
#  'On-Niqce server',
#  'fiction',
#  'statutory liberalism',
#  'Product specification',
#  'turfjara',
#  'Mineralization',
#  'Yes Creative Work',
#  'propoetics',
#  'Quickstop Sell',
#  'Gunpowder Product',
#  'Joseph Haydn',
#  'compactifility',
#  'diabetes',
#  'Qualatch',
#  'VDM van',
#  'song of a song',
#  'Indian Jungle Mercury',
#  'infuse',
#  'reuse',
#  'hermit',
#  'Dishquishingseek',
#  'Kingping',
#  'Product design',
#  'Arthums creative work',
#  'Wird wire',
#  'Neoread',
#  'The Mysinion Directions',
#  'Godarioda',
#  'Hers Martink',
#  'Product Machines',
#  'Versig Leves',
#  'Futurama',
#  'brim aggressor',
#  'Viciouson Hereditary Viciouson',
#  'Adam and Eve',
#  'copper',
#  'vice versa',
#  'List_of_poets_by_Berlin_poets',
#  'Vestibuli Oplenitus',
#  'product product',
#  'Gem engine',
#  'billions',
#  'freedom of religion',
#  'Dione',
#  'Gamalteca',
#  'To product',
#  'beliuf',
#  'product',
#  'Epistemology',
#  'complex complex',
#  'Wiring inferior',
#  'photon',
#  'Master engine',
#  'Vulturvinti',
#  'Tranformation',
#  'intelligent design',
#  'homemaker',
#  'Tvi',
#  'Ketouth',
#  "Fulhard's Saturn",
#  'Works Almanac',
#  'The President',
#  'intelligent design',
#  'computer',
#  'Amtech card',
#  'Reproductive Constantine Series',
#  'Alfarez of Carragen',
#  'ton',
#  'product',
#  'Pratigue of return',
#  'autoconverter',
#  'passages',
#  'transformation',
#  'catalyst',
#  'The Oufhof Prange',
#  'Dutch Mare',
#  'Product design',
#  'dilution',
#  'product deb',
#  'The Blue Law',
#  'Dewiyoto Okatomi',
#  'Venka Parta',
#  'CFC',
#  'embedded synthesis',
#  'Net Cartron',
#  'Nord (neuralhybiology),',
#  'The Threepsines',
#  'Octavius',
#  'diam',
#  'The Answers',
#  'Plato',
#  'Richard Taylor',
#  'Ruth Keene',
#  'incompetence',
#  'product display',
#  'Ding Laden Amendment',
#  'mythology',
#  'Autobiography',
#  'Heror of Humanity',
#  'Mexism',
#  'product',
#  'Hausdorff product',
#  'Product line',
#  'Ludwig van Beethoven',
#  'William Williams',
#  'Franland Dennona',
#  'The Velusin and the Orange of Valisin',
#  'Doom signal',
#  'Tulle Among Tulle Among Tulle',
#  "Halley's Market",
#  "Epstonia's Trilogy",
#  'Patthazor',
#  'infinitive',
#  'Death Which 24',
#  'The Divided Blue Slue',
#  'The Warm-Skinner',
#  'Machina Scisso',
#  'P-pyruvianism',
#  'Mesisen',
#  'product additive',
#  'uninitiation',
#  'creationism',
#  'polyonym',
#  'Caeneid',
#  'Port Perry',
#  'Lord Maulik',
#  'Grand Tank Tank',
#  'reed',
#  'Dianica',
#  'Creation Overton',
#  'discretization',
#  'borbidine',
#  'record label',
#  'myths',
#  'quasioo',
#  'Divine providence',
#  'midiamid',
#  'OCaml solid',
#  'Funrahman Ahmad',
#  'via regenerative crisis',
#  'Dumm Fudd',
#  'mesitotic tomammary tomammary tomammary tomammary',
#  'varanvaran',
#  'gound work',
#  'Autorata',
#  'Harry Nelson',
#  'Brian Gruff',
#  'SFM-BIND',
#  'product dust',
#  'invocation',
#  'Product of art',
#  'Therish',
#  'Michael Say',
#  'World War I',
#  'Mixdisc',
#  'Semi-Out Oft',
#  'Agricola',
#  'Hercules computer',
#  'Doom',
#  "Goin's Rough Angel",
#  'piece trigger',
#  'homebeat',
#  'properties',
#  'product',
#  'Scottish Devotional Visual Initiative',
#  'Ferratif',
#  'A product',
#  'Pulp',
#  'Ursula Reborn',
#  'pit index',
#  'Didache of Temela',
#  'product playback',
#  'From Beauty',
#  'Cambria',
#  'Workskills',
#  'product paint',
#  'Ontonio FÃ¼hrer',
#  'Enoch (creative work)',
#  'compact',
#  'periwatertonophy',
#  'creationism',
#  'Reslogion',
#  'DK-Dart',
#  'global warming',
#  'habeas corner',
#  'Derivative work',
#  'Josaph Louis Lagrange',
#  'Placement Placement Planement',
#  'polyatomy',
#  'nymph intervention',
#  'Wire',
#  'Novara',
#  'Real Turk',
#  'Ptolemy',
#  'Elfqnort',
#  'Americans',
#  'FireWire',
#  'Skeldolatresus',
#  'H-H-B/S',
#  'Fuduhara',
#  'Marvel Universe Marker',
#  "Creation of A'Three",
#  'deficit deficit',
#  'papyrotype',
#  'datatheoram',
#  "Learner's Lab",
#  'Malta',
#  'Aliza Aliza',
#  'The Type of Creative Work',
#  'Vom Mandelboro',
#  "Worksus' Creative Works",
#  'creativism',
#  'Riquet Sir Riquet Sir',
#  'Isabella',
#  'Athena',
#  'Deavor and Rights',
#  'Creative Action',
#  "Gilves' And Gilves's And Gilves'u Doctors",
#  'Doctor Doctor',
#  'tobacco',
#  'game competition',
#  'Autobons',
#  'Dione',
#  'conversation}',
#  'compact disc',
#  'Creation Work',
#  'invertebral pressure',
#  'Pascal product',
#  'In vivis',
#  'function',
#  'The Agrippanilla',
#  'friedrich Abelson',
#  'George Mason',
#  'Pronogonid',
#  'New South Wales',
#  'Libertatiss',
#  'Menbish',
#  'Scifsordeninger Scifsordininger',
#  'Voyage of the Dominion',
#  'Reme',
#  'quain',
#  'Howard Sibtler',
#  'Protestantism',
#  'metamorphosis',
#  'Audiborio',
#  'Product Name',
#  'product bus',
#  'Worcestershire Anthology',
#  'amiljus laquaris',
#  'PETIT Product',
#  'delimitation',
#  'Plan de la reine',
#  'Chattahooches',
#  'shilling',
#  'monophyletic',
#  'tensor call',
#  'waste product',
#  'Aide-Tide',
#  'double-plating',
#  'product',
#  'gelosynthesis',
#  'The Tomlins',
#  'staff distribution',
#  'reeligk',
#  'production',
#  'Conversion of fiction',
#  'nodem',
#  'Bletchley',
#  'physics',
#  'Hersholiton',
#  'Gaothi Mankaka',
#  'sexual entity',
#  'piano',
#  'The Creative Works of Arube the Strauss',
#  'Banin product',
#  'Tjadarsi',
#  'groups of products',
#  'production code',
#  'Plot brother',
#  'The Triumph of the World',
#  'mutation',
#  "Devil's End",
#  'Machiavelli',
#  'intel',
#  'himming',
#  'idealism',
#  'product design',
#  'Cadver discarding',
#  'H-H-B/S',
#  'morality',
#  'Kurthusianism',
#  'The Creative Work',
#  'Plastic duct',
#  'Deciding and Refuting Effects Attention',
#  'Enigma',
#  'hereditary settlement',
#  'copyright',
#  'Rayber Rayber Rayber Rayber',
#  'powder',
#  'Wide-area funition',
#  'neologism',
#  'Deh Deh',
#  'historical evolution',
#  'Creative Composition',
#  'product theory',
#  "Moore's Law",
#  'Graewald',
#  'Trapezote',
#  'clotting']

# %%
with open(YAGO_QEC_PATH, "w", encoding='utf-8') as fp:
    json.dump(yago_qec, fp, ensure_ascii=False, indent=4)
